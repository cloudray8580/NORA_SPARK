# %%
import findspark
findspark.init() # this must be executed before the below import

# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext
from pyspark.sql import SparkSession
from pyspark import SparkFiles

# %%
import ray
import time
import rtree
from rtree import index
import pandas as pd
import numpy as np
from numpy import genfromtxt
import threading
import pyarrow as pa
import pyarrow.parquet as pq

# %%
from NORAPartitionTree import *

# %%
conf = SparkConf().setAll([("spark.executor.memory", "24g"),("spark.driver.memory","24g"),
                           ("spark.memory.offHeap.enabled",True),("spark.memory.offHeap.size","16g"),
                          ("spark.driver.maxResultSize", "16g")])

sc = SparkContext(conf=conf)
sqlContext = SQLContext(sc)

# %%
def process_chunk_row(row, used_dims, partition_tree, pid_data_dict, count, k):
    if count[0] % 100000 == 0:
        print('proces',k,'has routed',count[0],'rows')
    count[0] += 1
    row_numpy = row.to_numpy()
    row_point = row_numpy[used_dims].tolist()
    pid = 0
    try:
        pid = partition_tree.get_pid_for_data_point(row_point)
    except:
        print(row_point)
    if pid in pid_data_dict:
        pid_data_dict[pid]+=[row_numpy.tolist()]
    else:
        pid_data_dict[pid]=[row_numpy.tolist()]

@ray.remote
def process_chunk(chunk, used_dims, partition_path, k, partition_tree):
    print("enter data routing process", k, '..')    
    pid_data_dict = {}
    count = [0]
    chunk.apply(lambda row: process_chunk_row(row, used_dims, partition_tree, pid_data_dict, count, k), axis=1)
    dict_id = ray.put(pid_data_dict)
    print("exit data routing process", k, ".")
    return dict_id

# %%
@ray.remote
def merge_epochs(parameters):
    #fs = pa.hdfs.connect()
    pids, epoch_count, hdfs_path, fs, merge_process = parameters
    for pid in pids:
        parquets = []
        for epoch in range(epoch_count):
            path = hdfs_path + "epoch_" + str(epoch) + '/partition_' + str(pid)+'.parquet'
            #print(path)
            try:
                par = pq.read_table(path)
                parquets.append(par)
            except:
                continue
        print("process", merge_process, "pid", pid, " len parquets (epochs):", len(parquets))
        if len(parquets) == 0:
            continue
        merged_parquet = pa.concat_tables(parquets)
        merge_path = hdfs_path + 'merged/partition_' + str(pid)+'.parquet'
        fw = fs.open_output_stream(merge_path)
        pq.write_table(merged_parquet, fw)
        fw.close()
    print('exit merge process', merge_process)

def merge_dict(base_dict, new_dict):
    for key, val in new_dict.items():
        if key in base_dict:
            base_dict[key] += val
        else:
            base_dict[key] = val
    new_dict.clear()

def dump_dict_2_hdfs_epoch(merged_dict, column_names, hdfs_path, fs, epoch):
    #print('= = = start dumping in main thread = = =')
    for pid, val in merged_dict.items():
        #print("writing to pid:",pid)
        path = hdfs_path + 'epoch_'+ str(epoch) +'/partition_' + str(pid) + '.parquet'
        pdf = pd.DataFrame(val, columns=column_names)
        adf = pa.Table.from_pandas(pdf)
        #fw = fs.open(path, 'wb')
        fw = fs.open_output_stream(path) # it seems the new version does not have the open function
        pq.write_table(adf, fw)
        fw.close()
    #print('= = = exit dumping = = =')

# %%
def batch_data_parallel(table_path, partition_path, chunk_size, used_dims, hdfs_path, num_dims, num_process, hdfs_private_ip):
    
    begin_time = time.time()
    
    ray.init(num_cpus=num_process)
    
    # column names for pandas dataframe
    cols = [i for i in range(num_dims)]
    col_names = ['_c'+str(i) for i in range(num_dims)]
    
    # pyarrow parquent append
    fs = pa.fs.HadoopFileSystem(hdfs_private_ip, port=9000, user='hdfs', replication=1)
    
    partition_tree = PartitionTree(len(used_dims))
    partition_tree.load_tree(partition_path)
    
    # chunks
    chunk_count = 0
    epoch_count = 0
    
    # collect object refs
    result_ids = []
    last_batch_ids = [] 
    first_loop = True
    
    for chunk in pd.read_table(table_path, delimiter='|', usecols=cols, names=col_names, chunksize=chunk_size):
        print('reading chunk: ', chunk_count)
        
        chunk_id = ray.put(chunk)
        result_id = process_chunk.remote(chunk_id, used_dims, partition_path, chunk_count, partition_tree)
        
        del chunk_id
        result_ids.append(result_id)
        del result_id
        
        # after all process allocated a chunk, process and dump the data
        if chunk_count % num_process == num_process - 1:
            
            if first_loop:
                first_loop = False
                last_batch_ids = result_ids.copy()
                result_ids.clear()
                chunk_count += 1
                continue
            else:
                print("= = = Process Dump For Chunk", chunk_count-2*num_process+1, "to", chunk_count-num_process, "= = =")
                base_dict = {}
                while len(last_batch_ids):
                    done_id, last_batch_ids = ray.wait(last_batch_ids)
                    dict_id = ray.get(done_id[0])
                    result_dict = ray.get(dict_id)
                    merge_dict(base_dict, result_dict)
                dump_dict_2_hdfs_epoch(base_dict, col_names, hdfs_path, fs, epoch_count) # consider whether we should use another process
                epoch_count += 1
                base_dict.clear()
                print("= = = Finish Dump For Chunk", chunk_count-2*num_process+1, "to", chunk_count-num_process, "= = =")
                last_batch_ids = result_ids.copy()
                result_ids.clear()
                
            current_time = time.time()
            time_elapsed = current_time - begin_time
            print("= = = TOTAL PROCESSED SO FAR:", (chunk_count-num_process+1) * chunk_size,"ROWS. TIME SPENT:", time_elapsed, "SECONDS = = =")
                
        chunk_count += 1
        
    # process the last few batches
    print("= = = Process Dump For Last Few Chunks = = =")
    base_dict = {}
    while len(last_batch_ids):
        done_id, last_batch_ids = ray.wait(last_batch_ids)
        dict_id = ray.get(done_id[0])
        result_dict = ray.get(dict_id)
        merge_dict(base_dict, result_dict)
    dump_dict_2_hdfs_epoch(base_dict, col_names, hdfs_path, fs, epoch_count)
    epoch_count += 1
    base_dict.clear()
    last_batch_ids.clear()

    base_dict = {}
    while len(result_ids):
        done_id, result_ids = ray.wait(result_ids)
        dict_id = ray.get(done_id[0])
        result_dict = ray.get(dict_id)
        merge_dict(base_dict, result_dict)
    result_ids.clear() # clear up the references
    dump_dict_2_hdfs_epoch(base_dict, col_names, hdfs_path, fs, epoch_count)
    epoch_count += 1
    base_dict.clear()
    result_ids.clear()
    
    
    # Merge all the epochs
    print("= = = Start Merging the Epochs = = =")
    leaves = partition_tree.get_leaves()
    pids = [leaf.nid for leaf in leaves]
    steps = len(pids) // num_process
    not_ready_ids = []
    for i in range(num_process):
        sub_pids = pids[i*steps:(i+1)*steps]
        if i == num_process - 1:
            sub_pids = pids[i*steps:]
        rid = merge_epochs.remote([sub_pids, epoch_count, hdfs_path, fs, i])
        not_ready_ids.append(rid)
        
    while len(not_ready_ids):
        ready_ids, not_ready_ids = ray.wait(not_ready_ids)
    
    ray.shutdown()
    
    finish_time = time.time()
    print('= = = = = TOTAL DATA ROUTING AND PERISITING TIME:', finish_time - begin_time, "= = = = =")

# %%
# = = = Configuration (UBDA Cloud Centos) = = =
scale_factor = 100
table_base_path = '/media/datadrive1/TPCH/dbgen/'
table_path = table_base_path + 'lineitem_' + str(scale_factor) + '.tbl'

num_process = 6
chunk_size = 2000000 
# 6M rows = about 1GB raw data

num_dims = 16
used_dims = [1,2,3,4]

# base path of HDFS
hdfs_private_ip = '192.168.6.62'
hdfs_base_path = 'hdfs://192.168.6.62:9000/user/cloudray/'

problem_type = 1

nora_hdfs = hdfs_base_path + 'NORA/prob' + str(problem_type) + '/'
qdtree_hdfs = hdfs_base_path + 'QdTree/prob' + str(problem_type) + '/'
kdtree_hdfs = hdfs_base_path + 'KDTree/prob' + str(problem_type) + '/'

# base path of Partition
partition_base_path = '/home/centos/PartitionLayout/'

nora_partition = partition_base_path + 'prob' + str(problem_type) + '_nora'
qdtree_partition = partition_base_path + 'prob' + str(problem_type) + '_qdtree'
kdtree_partition = partition_base_path + 'prob' + str(problem_type) + '_kdtree'

# %%
# # if the merge phase failed, rerun with this one
# # Adjust epoch_count, num_process, partition_tree.load_tree(...), and qdtree_hdfs !!!

# ray.init(num_cpus=1)
# fs = pa.fs.HadoopFileSystem('192.168.6.62', port=9000, user='hdfs', replication=1)
    
# partition_tree = PartitionTree(len(used_dims))
# partition_tree.load_tree(qdtree_partition)

# epoch_count = 51

# leaves = partition_tree.get_leaves()
# pids = [leaf.nid for leaf in leaves]
# steps = len(pids) // num_process
# not_ready_ids = []
# for i in range(num_process):
#     sub_pids = pids[i*steps:(i+1)*steps]
#     if i == num_process - 1:
#         sub_pids = pids[i*steps:]
#     rid = merge_epochs.remote([sub_pids, epoch_count, qdtree_hdfs, fs, i])
#     not_ready_ids.append(rid)

# %%
# # = = = Execution = = =
# if __name__ == '__main__':
#     batch_data_parallel(table_path, nora_partition, chunk_size, used_dims, nora_hdfs, num_dims, num_process, hdfs_private_ip)
#     print('finish nora data routing..')
#     batch_data_parallel(table_path, qdtree_partition, chunk_size, used_dims, qdtree_hdfs, num_dims, num_process, hdfs_private_ip)
#     print('finish qdtree data routing..')
#     batch_data_parallel(table_path, kdtree_partition, chunk_size, used_dims, kdtree_hdfs, num_dims, num_process, hdfs_private_ip)
#     print('finish kdtree data routing..')
# Out:
# 2021-07-01 14:51:53,884	INFO services.py:1164 -- View the Ray dashboard at http://127.0.0.1:8265
# reading chunk:  0
# (pid=30412) enter data routing process 0 ..
# (pid=30412) proces 0 has routed 0 rows
# reading chunk:  1
# (pid=30415) enter data routing process 1 ..
# (pid=30412) proces 0 has routed 100000 rows
# (pid=30415) proces 1 has routed 0 rows
# reading chunk:  2
# (pid=30412) proces 0 has routed 200000 rows
# (pid=30409) enter data routing process 2 ..
# (pid=30415) proces 1 has routed 100000 rows
# (pid=30409) proces 2 has routed 0 rows
# reading chunk:  3
# (pid=30412) proces 0 has routed 300000 rows
# (pid=30415) proces 1 has routed 200000 rows
# (pid=30411) enter data routing process 3 ..
# (pid=30409) proces 2 has routed 100000 rows
# (pid=30411) proces 3 has routed 0 rows
# (pid=30412) proces 0 has routed 400000 rows
# reading chunk:  4
# (pid=30415) proces 1 has routed 300000 rows
# (pid=30409) proces 2 has routed 200000 rows
# (pid=30413) enter data routing process 4 ..
# (pid=30411) proces 3 has routed 100000 rows
# (pid=30412) proces 0 has routed 500000 rows
# (pid=30413) proces 4 has routed 0 rows
# (pid=30415) proces 1 has routed 400000 rows
# reading chunk:  5
# (pid=30409) proces 2 has routed 300000 rows
# (pid=30411) proces 3 has routed 200000 rows
# (pid=30412) proces 0 has routed 600000 rows
# (pid=30410) enter data routing process 5 ..
# (pid=30413) proces 4 has routed 100000 rows
# (pid=30415) proces 1 has routed 500000 rows
# (pid=30410) proces 5 has routed 0 rows
# (pid=30409) proces 2 has routed
# (pid=30409)  400000 rows
# reading chunk:  6
# (pid=30411) proces 3 has routed 300000 rows
# (pid=30412) proces 0 has routed 700000 rows
# (pid=30413) proces 4 has routed 200000 rows
# (pid=30415) proces 1 has routed 600000 rows
# (pid=30410) proces 5 has routed 100000 rows
# (pid=30409) proces 2 has routed 500000 rows
# reading chunk:  7
# (pid=30411) proces 3 has routed 400000 rows
# (pid=30412) proces 0 has routed 800000 rows
# (pid=30413) proces 4 has routed 300000 rows
# (pid=30415) proces 1 has routed 700000 rows
# (pid=30410) proces 5 has routed 200000 rows
# (pid=30409) proces 2 has routed 600000 rows
# (pid=30412) proces 0 has routed 900000 rows
# (pid=30411) proces 3 has routed 500000 rows
# reading chunk:  8
# (pid=30413) proces 4 has routed 400000 rows
# (pid=30415) proces 1 has routed 800000 rows
# (pid=30410) proces 5 has routed 300000 rows
# (pid=30409) proces 2 has routed 700000 rows
# (pid=30411) proces 3 has routed 600000 rows
# (pid=30412) proces 0 has routed 1000000 rows
# (pid=30415) proces 1 has routed 900000 rows
# (pid=30413) proces 4 has routed 500000 rows
# (pid=30410) proces 5 has routed 400000 rows
# reading chunk:  9
# (pid=30409) proces 2 has routed 800000 rows
# (pid=30412) proces 0 has routed 1100000 rows
# (pid=30411) proces 3 has routed 700000 rows
# (pid=30415) proces 1 has routed 1000000 rows
# (pid=30413) proces 4 has routed 600000 rows
# (pid=30410) proces 5 has routed 500000 rows
# (pid=30409) proces 2 has routed 900000 rows
# reading chunk:  10
# (pid=30412) proces 0 has routed 1200000 rows
# (pid=30411) proces 3 has routed 800000 rows
# (pid=30415) proces 1 has routed 1100000 rows
# (pid=30413) proces 4 has routed 700000 rows
# (pid=30410) proces 5 has routed 600000 rows
# (pid=30409) proces 2 has routed 1000000 rows
# reading chunk:  11
# (pid=30411) proces 3 has routed 900000 rows
# (pid=30412) proces 0 has routed 1300000 rows
# (pid=30415) proces 1 has routed 1200000 rows
# = = = Process Dump For Chunk 0 to 5 = = =
# (pid=30413) proces 4 has routed 800000 rows
# (pid=30410) proces 5 has routed 700000 rows
# (pid=30409) proces 2 has routed 1100000 rows
# (pid=30412) proces 0 has routed 1400000 rows
# (pid=30411) proces 3 has routed 1000000 rows
# (pid=30415) proces 1 has routed 1300000 rows
# (pid=30413) proces 4 has routed 900000 rows
# (pid=30409) proces 2 has routed 1200000 rows
# (pid=30410) proces 5 has routed 800000 rows
# (pid=30412) proces 0 has routed 1500000 rows
# (pid=30411) proces 3 has routed 1100000 rows
# (pid=30415) proces 1 has routed 1400000 rows
# (pid=30410) proces 5 has routed 900000 rows
# (pid=30413) proces 4 has routed 1000000 rows
# (pid=30409) proces 2 has routed 1300000 rows
# (pid=30411) proces 3 has routed 1200000 rows
# (pid=30412) proces 0 has routed 1600000 rows
# (pid=30415) proces 1 has routed 1500000 rows
# (pid=30413) proces 4 has routed 1100000 rows
# (pid=30409) proces 2 has routed 1400000 rows
# (pid=30410) proces 5 has routed 1000000 rows
# (pid=30412) proces 0 has routed 1700000 rows
# (pid=30411) proces 3 has routed 1300000 rows
# (pid=30415) proces 1 has routed 1600000 rows
# (pid=30413) proces 4 has routed 1200000 rows
# (pid=30409) proces 2 has routed 1500000 rows
# (pid=30410) proces 5 has routed 1100000 rows
# (pid=30412) proces 0 has routed 1800000 rows
# (pid=30411) proces 3 has routed 1400000 rows
# (pid=30415) proces 1 has routed 1700000 rows
# (pid=30410) proces 5 has routed 1200000 rows
# (pid=30413) proces 4 has routed 1300000 rows
# (pid=30409) proces 2 has routed 1600000 rows
# (pid=30412) proces 0 has routed 1900000 rows
# (pid=30411) proces 3 has routed 1500000 rows
# (pid=30415) proces 1 has routed 1800000 rows
# (pid=30410) proces 5 has routed 1300000 rows
# (pid=30409) proces 2 has routed 1700000 rows
# (pid=30413) proces 4 has routed 1400000 rows
# (pid=30415) proces 1 has routed 1900000 rows
# (pid=30411) proces 3 has routed 1600000 rows
# (pid=30410) proces 5 has routed 1400000 rows
# (pid=30409) proces 2 has routed 1800000 rows
# (pid=30413) proces 4 has routed 1500000 rows
# (pid=30411) proces 3 has routed 1700000 rows
# (pid=30410) proces 5 has routed 1500000 rows
# (pid=30409) proces 2 has routed 1900000 rows
# (pid=30412) exit data routing process 0 .
# (pid=30413) proces 4 has routed 1600000 rows
# (pid=30411) proces 3 has routed 1800000 rows
# (pid=30412) enter data routing process 6 ..
# (pid=30410) proces 5 has routed 1600000 rows
# (pid=30412) proces 6 has routed 0 rows
# (pid=30413) proces 4 has routed 1700000 rows
# (pid=30415) exit data routing process 1 .
# (pid=30411) proces 3 has routed 1900000 rows
# (pid=30410) proces 5 has routed 1700000 rows
# (pid=30415) enter data routing process 7 ..
# (pid=30412) proces 6 has routed 100000 rows
# (pid=30413) proces 4 has routed 1800000 rows
# (pid=30415) proces 7 has routed 0 rows
# (pid=30409) exit data routing process 2 .
# (pid=30410) proces 5 has routed 1800000 rows
# (pid=30412) proces 6 has routed 200000 rows
# (pid=30413) proces 4 has routed 1900000 rows
# (pid=30409) enter data routing process 8 ..
# (pid=30415) proces 7 has routed 100000 rows
# (pid=30409) proces 8 has routed 0 rows
# (pid=30410) proces 5 has routed 1900000 rows
# (pid=30412) proces 6 has routed 300000 rows
# (pid=30415) proces 7 has routed 200000 rows
# (pid=30411) exit data routing process 3 .
# (pid=30409) proces 8 has routed 100000 rows
# (pid=30412) proces 6 has routed 400000 rows
# (pid=30411) enter data routing process 9 ..
# (pid=30415) proces 7 has routed 300000 rows
# (pid=30411) proces 9 has routed 0 rows
# (pid=30409) proces 8 has routed 200000 rows
# (pid=30413) exit data routing process 4 .
# (pid=30412) proces 6 has routed 500000 rows
# (pid=30415) proces 7 has routed 400000 rows
# (pid=30411) proces 9 has routed 100000 rows
# (pid=30413) enter data routing process 10 ..
# (pid=30409) proces 8 has routed 300000 rows
# (pid=30410) exit data routing process 5 .
# (pid=30413) proces 10 has routed 0 rows
# (pid=30412) proces 6 has routed 600000 rows
# (pid=30415) proces 7 has routed 500000 rows
# (pid=30410) enter data routing process 11 ..
# (pid=30411) proces 9 has routed 200000 rows
# (pid=30409) proces 8 has routed 400000 rows
# (pid=30410) proces 11 has routed 0 rows
# (pid=30413) proces 10 has routed 100000 rows
# (pid=30412) proces 6 has routed 700000 rows
# (pid=30415) proces 7 has routed 600000 rows
# (pid=30411) proces 9 has routed 300000 rows
# (pid=30409) proces 8 has routed 500000 rows
# (pid=30410) proces 11 has routed 100000 rows
# (pid=30413) proces 10 has routed 200000 rows
# (pid=30412) proces 6 has routed 800000 rows
# (pid=30415) proces 7 has routed 700000 rows
# (pid=30411) proces 9 has routed 400000 rows
# (pid=30409) proces 8 has routed 600000 rows
# (pid=30410) proces 11 has routed 200000 rows
# (pid=30413) proces 10 has routed 300000 rows
# (pid=30412) proces 6 has routed 900000 rows
# (pid=30415) proces 7 has routed 800000 rows
# (pid=30411) proces 9 has routed 500000 rows
# (pid=30409) proces 8 has routed 700000 rows
# (pid=30410) proces 11 has routed 300000 rows
# (pid=30413) proces 10 has routed 400000 rows
# (pid=30412) proces 6 has routed 1000000 rows
# (pid=30415) proces 7 has routed 900000 rows
# (pid=30411) proces 9 has routed 600000 rows
# (pid=30410) proces 11 has routed 400000 rows
# (pid=30409) proces 8 has routed 800000 rows
# (pid=30413) proces 10 has routed 500000 rows
# (pid=30412) proces 6 has routed 1100000 rows
# (pid=30415) proces 7 has routed 1000000 rows
# (pid=30411) proces 9 has routed 700000 rows
# (pid=30410) proces 11 has routed 500000 rows
# (pid=30409) proces 8 has routed 900000 rows
# (pid=30413) proces 10 has routed 600000 rows
# (pid=30412) proces 6 has routed 1200000 rows
# (pid=30415) proces 7 has routed 1100000 rows
# (pid=30411) proces 9 has routed 800000 rows
# (pid=30410) proces 11 has routed 600000 rows
# (pid=30409) proces 8 has routed 1000000 rows
# (pid=30413) proces 10 has routed 700000 rows
# (pid=30412) proces 6 has routed 1300000 rows
# (pid=30411) proces 9 has routed 900000 rows
# (pid=30415) proces 7 has routed 1200000 rows
# (pid=30409) proces 8 has routed 1100000 rows
# (pid=30410) proces 11 has routed 700000 rows
# (pid=30413) proces 10 has routed 800000 rows
# (pid=30412) proces 6 has routed 1400000 rows
# (pid=30415) proces 7 has routed 1300000 rows
# (pid=30411) proces 9 has routed 1000000 rows
# (pid=30410) proces 11 has routed 800000 rows
# (pid=30409) proces 8 has routed 1200000 rows
# (pid=30413) proces 10 has routed 900000 rows
# (pid=30412) proces 6 has routed 1500000 rows
# (pid=30415) proces 7 has routed 1400000 rows
# (pid=30411) proces 9 has routed 1100000 rows
# (pid=30410) proces 11 has routed 900000 rows
# (pid=30409) proces 8 has routed 1300000 rows
# (pid=30413) proces 10 has routed 1000000 rows
# (pid=30412) proces 6 has routed 1600000 rows
# (pid=30415) proces 7 has routed 1500000 rows
# (pid=30409) proces 8 has routed 1400000 rows
# (pid=30411) proces 9 has routed 1200000 rows
# (pid=30410) proces 11 has routed 1000000 rows
# (pid=30413) proces 10 has routed 1100000 rows
# (pid=30412) proces 6 has routed 1700000 rows
# (pid=30415) proces 7 has routed 1600000 rows
# (pid=30411) proces 9 has routed 1300000 rows
# (pid=30410) proces 11 has routed 1100000 rows
# (pid=30409) proces 8 has routed 1500000 rows
# (pid=30413) proces 10 has routed 1200000 rows
# (pid=30412) proces 6 has routed 1800000 rows
# (pid=30415) proces 7 has routed 1700000 rows
# (pid=30411) proces 9 has routed 1400000 rows
# (pid=30410) proces 11 has routed 1200000 rows
# (pid=30409) proces 8 has routed 1600000 rows
# (pid=30413) proces 10 has routed 1300000 rows
# (pid=30412) proces 6 has routed 1900000 rows
# (pid=30415) proces 7 has routed 1800000 rows
# (pid=30411) proces 9 has routed 1500000 rows
# (pid=30409) proces 8 has routed 1700000 rows
# (pid=30410) proces 11 has routed 1300000 rows
# (pid=30413) proces 10 has routed 1400000 rows
# (pid=30415) proces 7 has routed 1900000 rows
# (pid=30411) proces 9 has routed 1600000 rows
# (pid=30409) proces 8 has routed 1800000 rows
# (pid=30410) proces 11 has routed 1400000 rows
# (pid=30413) proces 10 has routed 1500000 rows
# (pid=30411) proces 9 has routed 1700000 rows
# (pid=30412) exit data routing process 6 .
# (pid=30410) proces 11 has routed 1500000 rows
# (pid=30409) proces 8 has routed 1900000 rows
# (pid=30413) proces 10 has routed 1600000 rows
# (pid=30411) proces 9 has routed 1800000 rows
# (pid=30410) proces 11 has routed 1600000 rows
# (pid=30415) exit data routing process 7 .
# (pid=30413) proces 10 has routed 1700000 rows
# = = = Finish Dump For Chunk(pid=30411) proces 9 has routed 1900000 rows 0 to 5 = = =
# = = = TOTAL PROCESSED SO FAR: 12000000 ROWS. TIME SPENT: 224.59351110458374 SECONDS = = =
#
# (pid=30410) proces 11 has routed 1700000 rows
# (pid=30413) proces 10 has routed 1800000 rows
# (pid=30409) exit data routing process 8 .
# (pid=30410) proces 11 has routed 1800000 rows
# reading chunk:  12
# (pid=30413) proces 10 has routed 1900000 rows
# (pid=30409) enter data routing process 12 ..
# (pid=30410) proces 11 has routed 1900000 rows
# (pid=30411) exit data routing process 9 .
# (pid=30409) proces 12 has routed 0 rows
# reading chunk:  13
# (pid=30409) proces 12 has routed 100000 rows
# (pid=30411) enter data routing process 13 ..
# (pid=30411) proces 13 has routed 0 rows
# (pid=30413) exit data routing process 10 .
# reading chunk:  14
# (pid=30409) proces 12 has routed 200000 rows
# (pid=30410) exit data routing process 11 .
# (pid=30411) proces 13 has routed 100000 rows
# (pid=30413) enter data routing process 14 ..
# (pid=30413) proces 14 has routed 0 rows
# (pid=30409) proces 12 has routed 300000 rows
# reading chunk:  15
# (pid=30411) proces 13 has routed 200000 rows
# (pid=30413) proces 14 has routed 100000 rows
# (pid=30410) enter data routing process 15 ..
# (pid=30409) proces 12 has routed 400000 rows
# (pid=30410) proces 15 has routed 0 rows
# (pid=30411) proces 13 has routed 300000 rows
# reading chunk:  16
# (pid=30413) proces 14 has routed 200000 rows
# (pid=30409) proces 12 has routed 500000 rows
# (pid=30410) proces 15 has routed 100000 rows
# (pid=30415) enter data routing process 16 ..
# (pid=30411) proces 13 has routed 400000 rows
# (pid=30415) proces 16 has routed 0 rows
# (pid=30413) proces 14 has routed 300000 rows
# reading chunk:  17
# (pid=30409) proces 12 has routed 600000 rows
# (pid=30410) proces 15 has routed 200000 rows
# (pid=30411) proces 13 has routed 500000 rows
# = = = Process Dump For Chunk 6 to 11 = = =
# (pid=30415) proces 16 has routed 100000 rows
# (pid=30412) enter data routing process 17 ..
# (pid=30413) proces 14 has routed 400000 rows
# (pid=30412) proces 17 has routed 0 rows
# (pid=30409) proces 12 has routed 700000 rows
# (pid=30410) proces 15 has routed 300000 rows
# (pid=30411) proces 13 has routed 600000 rows
# (pid=30415) proces 16 has routed 200000 rows
# (pid=30413) proces 14 has routed 500000 rows
# (pid=30412) proces 17 has routed 100000 rows
# (pid=30409) proces 12 has routed 800000 rows
# (pid=30410) proces 15 has routed 400000 rows
# (pid=30411) proces 13 has routed 700000 rows
# (pid=30415) proces 16 has routed 300000 rows
# (pid=30412) proces 17 has routed 200000 rows
# (pid=30413) proces 14 has routed 600000 rows
# (pid=30409) proces 12 has routed 900000 rows
# (pid=30410) proces 15 has routed 500000 rows
# (pid=30411) proces 13 has routed 800000 rows
# (pid=30415) proces 16 has routed 400000 rows
# (pid=30412) proces 17 has routed 300000 rows
# (pid=30413) proces 14 has routed 700000 rows
# (pid=30409) proces 12 has routed 1000000 rows
# (pid=30410) proces 15 has routed 600000 rows
# (pid=30411) proces 13 has routed 900000 rows
# (pid=30415) proces 16 has routed 500000 rows
# (pid=30412) proces 17 has routed 400000 rows
# (pid=30413) proces 14 has routed 800000 rows
# (pid=30409) proces 12 has routed 1100000 rows
# (pid=30410) proces 15 has routed 700000 rows
# (pid=30411) proces 13 has routed 1000000 rows
# (pid=30415) proces 16 has routed 600000 rows
# (pid=30412) proces 17 has routed 500000 rows
# (pid=30413) proces 14 has routed 900000 rows
# (pid=30410) proces 15 has routed 800000 rows
# (pid=30409) proces 12 has routed 1200000 rows
# (pid=30411) proces 13 has routed 1100000 rows
# (pid=30415) proces 16 has routed 700000 rows
# (pid=30412) proces 17 has routed 600000 rows
# (pid=30413) proces 14 has routed 1000000 rows
# (pid=30410) proces 15 has routed 900000 rows
# (pid=30409) proces 12 has routed 1300000 rows
# (pid=30415) proces 16 has routed 800000 rows
# (pid=30411) proces 13 has routed 1200000 rows
# (pid=30412) proces 17 has routed 700000 rows
# (pid=30413) proces 14 has routed 1100000 rows
# (pid=30409) proces 12 has routed 1400000 rows
# (pid=30410) proces 15 has routed 1000000 rows
# (pid=30415) proces 16 has routed 900000 rows
# (pid=30411) proces 13 has routed 1300000 rows
# (pid=30412) proces 17 has routed 800000 rows
# (pid=30413) proces 14 has routed 1200000 rows
# (pid=30410) proces 15 has routed 1100000 rows
# (pid=30409) proces 12 has routed 1500000 rows
# (pid=30411) proces 13 has routed 1400000 rows
# (pid=30415) proces 16 has routed 1000000 rows
# (pid=30412) proces 17 has routed 900000 rows
# (pid=30413) proces 14 has routed 1300000 rows
# (pid=30410) proces 15 has routed 1200000 rows
# (pid=30409) proces 12 has routed 1600000 rows
# (pid=30415) proces 16 has routed 1100000 rows
# (pid=30411) proces 13 has routed 1500000 rows
# (pid=30412) proces 17 has routed 1000000 rows
# (pid=30413) proces 14 has routed 1400000 rows
# (pid=30410) proces 15 has routed 1300000 rows
# (pid=30409) proces 12 has routed 1700000 rows
# (pid=30415) proces 16 has routed 1200000 rows
# (pid=30411) proces 13 has routed 1600000 rows
# (pid=30412) proces 17 has routed 1100000 rows
# (pid=30410) proces 15 has routed 1400000 rows
# (pid=30413) proces 14 has routed 1500000 rows
# (pid=30409) proces 12 has routed 1800000 rows
# (pid=30411) proces 13 has routed 1700000 rows
# (pid=30415) proces 16 has routed 1300000 rows
# (pid=30412) proces 17 has routed 1200000 rows
# (pid=30413) proces 14 has routed 1600000 rows
# (pid=30409) proces 12 has routed 1900000 rows
# (pid=30410) proces 15 has routed 1500000 rows
# (pid=30411) proces 13 has routed 1800000 rows
# (pid=30415) proces 16 has routed 1400000 rows
# (pid=30412) proces 17 has routed 1300000 rows
# (pid=30413) proces 14 has routed 1700000 rows
# (pid=30410) proces 15 has routed 1600000 rows
# (pid=30411) proces 13 has routed 1900000 rows
# (pid=30415) proces 16 has routed 1500000 rows
# (pid=30412) proces 17 has routed 1400000 rows
# (pid=30413) proces 14 has routed 1800000 rows
# (pid=30410) proces 15 has routed 1700000 rows
# (pid=30415) proces 16 has routed 1600000 rows
# (pid=30409) exit data routing process 12 .
# (pid=30412) proces 17 has routed 1500000 rows
# (pid=30410) proces 15 has routed 1800000 rows
# (pid=30413) proces 14 has routed 1900000 rows
# (pid=30415) proces 16 has routed 1700000 rows
# (pid=30411) exit data routing process 13 .
# (pid=30412) proces 17 has routed 1600000 rows
# (pid=30410) proces 15 has routed 1900000 rows
# (pid=30415) proces 16 has routed 1800000 rows
# (pid=30412) proces 17 has routed 1700000 rows
# (pid=30415) proces 16 has routed 1900000 rows
# (pid=30413) exit data routing process 14 .
# (pid=30412) proces 17 has routed 1800000 rows
# (pid=30410) exit data routing process 15 .
# (pid=30412) proces 17 has routed 1900000 rows
# (pid=30415) exit data routing process 16 .
# = = = Finish Dump For Chunk(pid=30412) exit data routing process 17 . 6 to 11
# = = =
# = = = TOTAL PROCESSED SO FAR: 24000000 ROWS. TIME SPENT: 363.8040521144867 SECONDS = = =
# reading chunk:  18
# (pid=30412) enter data routing process 18 ..
# (pid=30412) proces 18 has routed 0 rows
# reading chunk:  19
# (pid=30415) enter data routing process 19 ..
# (pid=30412) proces 18 has routed 100000 rows
# (pid=30415) proces 19 has routed 0 rows
# reading chunk:  20
# (pid=30412) proces 18 has routed 200000 rows
# (pid=30415) proces 19 has routed 100000 rows
# (pid=30410) enter data routing process 20 ..
# (pid=30410) proces 20 has routed 0 rows
# (pid=30412) proces 18 has routed 300000 rows
# reading chunk:  21
# (pid=30415) proces 19 has routed 200000 rows
# (pid=30413) enter data routing process 21 ..
# (pid=30410) proces 20 has routed 100000 rows
# (pid=30412) proces 18 has routed 400000 rows
# (pid=30413) proces 21 has routed 0 rows
# (pid=30415) proces 19 has routed 300000 rows
# reading chunk:  22
# (pid=30410) proces 20 has routed 200000 rows
# (pid=30411) enter data routing process 22 ..
# (pid=30412) proces 18 has routed 500000 rows
# (pid=30413) proces 21 has routed 100000 rows
# (pid=30415) proces 19 has routed 400000 rows
# (pid=30411) proces 22 has routed 0 rows
# (pid=30410) proces 20 has routed 300000 rows
# reading chunk:  23
# (pid=30413) proces 21 has routed 200000 rows
# (pid=30412) proces 18 has routed 600000 rows
# = = = Process Dump For Chunk 12 to 17 = = =
# (pid=30415) proces 19 has routed 500000 rows
# (pid=30409) enter data routing process 23 ..
# (pid=30411) proces 22 has routed 100000 rows
# (pid=30410) proces 20 has routed 400000 rows
# (pid=30409) proces 23 has routed 0 rows
# (pid=30413) proces 21 has routed 300000 rows
# (pid=30412) proces 18 has routed 700000 rows
# (pid=30415) proces 19 has routed 600000 rows
# (pid=30411) proces 22 has routed 200000 rows
# (pid=30410) proces 20 has routed 500000 rows
# (pid=30409) proces 23 has routed 100000 rows
# (pid=30413) proces 21 has routed 400000 rows
# (pid=30412) proces 18 has routed 800000 rows
# (pid=30415) proces 19 has routed 700000 rows
# (pid=30411) proces 22 has routed 300000 rows
# (pid=30410) proces 20 has routed 600000 rows
# (pid=30409) proces 23 has routed 200000 rows
# (pid=30413) proces 21 has routed 500000 rows
# (pid=30412) proces 18 has routed 900000 rows
# (pid=30411) proces 22 has routed 400000 rows
# (pid=30415) proces 19 has routed 800000 rows
# (pid=30410) proces 20 has routed 700000 rows
# (pid=30409) proces 23 has routed 300000 rows
# (pid=30413) proces 21 has routed 600000 rows
# (pid=30412) proces 18 has routed 1000000 rows
# (pid=30411) proces 22 has routed 500000 rows
# (pid=30415) proces 19 has routed 900000 rows
# (pid=30409) proces 23 has routed 400000 rows
# (pid=30410) proces 20 has routed 800000 rows
# (pid=30413) proces 21 has routed 700000 rows
# (pid=30412) proces 18 has routed 1100000 rows
# (pid=30411) proces 22 has routed 600000 rows
# (pid=30415) proces 19 has routed 1000000 rows
# (pid=30409) proces 23 has routed 500000 rows
# (pid=30410) proces 20 has routed 900000 rows
# (pid=30413) proces 21 has routed 800000 rows
# (pid=30412) proces 18 has routed 1200000 rows
# (pid=30411) proces 22 has routed 700000 rows
# (pid=30415) proces 19 has routed 1100000 rows
# (pid=30409) proces 23 has routed 600000 rows
# (pid=30410) proces 20 has routed 1000000 rows
# (pid=30413) proces 21 has routed 900000 rows
# (pid=30412) proces 18 has routed 1300000 rows
# (pid=30411) proces 22 has routed 800000 rows
# (pid=30415) proces 19 has routed 1200000 rows
# (pid=30409) proces 23 has routed 700000 rows
# (pid=30410) proces 20 has routed 1100000 rows
# (pid=30412) proces 18 has routed 1400000 rows
# (pid=30413) proces 21 has routed 1000000 rows
# (pid=30411) proces 22 has routed 900000 rows
# (pid=30415) proces 19 has routed 1300000 rows
# (pid=30409) proces 23 has routed 800000 rows
# (pid=30410) proces 20 has routed 1200000 rows
# (pid=30412) proces 18 has routed 1500000 rows
# (pid=30413) proces 21 has routed 1100000 rows
# (pid=30411) proces 22 has routed 1000000 rows
# (pid=30415) proces 19 has routed 1400000 rows
# (pid=30409) proces 23 has routed 900000 rows
# (pid=30410) proces 20 has routed 1300000 rows
# (pid=30413) proces 21 has routed 1200000 rows
# (pid=30412) proces 18 has routed 1600000 rows
# (pid=30411) proces 22 has routed 1100000 rows
# (pid=30415) proces 19 has routed 1500000 rows
# (pid=30410) proces 20 has routed 1400000 rows
# (pid=30409) proces 23 has routed 1000000 rows
# (pid=30413) proces 21 has routed 1300000 rows
# (pid=30412) proces 18 has routed 1700000 rows
# (pid=30411) proces 22 has routed 1200000 rows
# (pid=30415) proces 19 has routed 1600000 rows
# (pid=30410) proces 20 has routed 1500000 rows
# (pid=30409) proces 23 has routed 1100000 rows
# (pid=30412) proces 18 has routed 1800000 rows
# (pid=30413) proces 21 has routed 1400000 rows
# (pid=30411) proces 22 has routed 1300000 rows
# (pid=30415) proces 19 has routed 1700000 rows
# (pid=30410) proces 20 has routed 1600000 rows
# (pid=30409) proces 23 has routed 1200000 rows
# (pid=30412) proces 18 has routed 1900000 rows
# (pid=30413) proces 21 has routed 1500000 rows
# (pid=30411) proces 22 has routed 1400000 rows
# (pid=30415) proces 19 has routed 1800000 rows
# (pid=30410) proces 20 has routed 1700000 rows
# (pid=30409) proces 23 has routed 1300000 rows
# (pid=30411) proces 22 has routed 1500000 rows
# (pid=30413) proces 21 has routed 1600000 rows
# (pid=30415) proces 19 has routed 1900000 rows
# (pid=30410) proces 20 has routed 1800000 rows
# (pid=30409) proces 23 has routed 1400000 rows
# (pid=30413) proces 21 has routed 1700000 rows
# (pid=30411) proces 22 has routed 1600000 rows
# (pid=30410) proces 20 has routed 1900000 rows
# (pid=30412) exit data routing process 18 .
# (pid=30409) proces 23 has routed 1500000 rows
# (pid=30413) proces 21 has routed 1800000 rows
# (pid=30411) proces 22 has routed 1700000 rows
# (pid=30415) exit data routing process 19 .
# (pid=30409) proces 23 has routed 1600000 rows
# (pid=30413) proces 21 has routed 1900000 rows
# (pid=30411) proces 22 has routed 1800000 rows
# (pid=30409) proces 23 has routed 1700000 rows
# (pid=30410) exit data routing process 20 .
# (pid=30411) proces 22 has routed 1900000 rows
# (pid=30409) proces 23 has routed 1800000 rows
# (pid=30409) proces 23 has routed 1900000 rows= = = Finish Dump For Chunk 12
# (pid=30413) exit data routing process 21 .
# to 17 = = =
# = = = TOTAL PROCESSED SO FAR: 36000000 ROWS. TIME SPENT: 494.1501626968384 SECONDS = = =
# (pid=30411) exit data routing process 22 .
# reading chunk:  24
# (pid=30411) enter data routing process 24 ..
# (pid=30409) exit data routing process 23 .
# (pid=30411) proces 24 has routed 0 rows
# reading chunk:  25
# (pid=30409) enter data routing process 25 ..
# (pid=30411) proces 24 has routed 100000 rows
# (pid=30409) proces 25 has routed 0 rows
# reading chunk:  26
# (pid=30411) proces 24 has routed 200000 rows
# (pid=30409) proces 25 has routed 100000 rows
# (pid=30413) enter data routing process 26 ..
# (pid=30413) proces 26 has routed 0 rows
# (pid=30411) proces 24 has routed 300000 rows
# (pid=30409) proces 25 has routed 200000 rows
# reading chunk:  27
# (pid=30413) proces 26 has routed 100000 rows
# (pid=30411) proces 24 has routed 400000 rows
# (pid=30410) enter data routing process 27 ..
# (pid=30409) proces 25 has routed 300000 rows
# (pid=30410) proces 27 has routed 0 rows
# (pid=30413) proces 26 has routed 200000 rowsreading chunk:  28
#
# (pid=30411) proces 24 has routed 500000 rows
# (pid=30409) proces 25 has routed 400000 rows
# (pid=30410) proces 27 has routed 100000 rows
# (pid=30415) enter data routing process 28 ..
# (pid=30415) proces 28 has routed 0 rows
# (pid=30413) proces 26 has routed 300000 rows
# (pid=30411) proces 24 has routed 600000 rows
# (pid=30410) proces 27 has routed 200000 rows
# (pid=30409) proces 25 has routed 500000 rows
# reading chunk:  29
# (pid=30415) proces 28 has routed 100000 rows
# = = = Process Dump For Chunk 18 to 23 = = =
# (pid=30413) proces 26 has routed 400000 rows
# (pid=30411) proces 24 has routed 700000 rows
# (pid=30412) enter data routing process 29 ..
# (pid=30410) proces 27 has routed 300000 rows
# (pid=30412) proces 29 has routed 0 rows
# (pid=30409) proces 25 has routed 600000 rows
# (pid=30415) proces 28 has routed 200000 rows
# (pid=30413) proces 26 has routed 500000 rows
# (pid=30411) proces 24 has routed 800000 rows
# (pid=30410) proces 27 has routed 400000 rows
# (pid=30412) proces 29 has routed 100000 rows
# (pid=30409) proces 25 has routed 700000 rows
# (pid=30415) proces 28 has routed 300000 rows
# (pid=30411) proces 24 has routed 900000 rows
# (pid=30413) proces 26 has routed 600000 rows
# (pid=30410) proces 27 has routed 500000 rows
# (pid=30412) proces 29 has routed 200000 rows
# (pid=30409) proces 25 has routed 800000 rows
# (pid=30415) proces 28 has routed 400000 rows
# (pid=30411) proces 24 has routed 1000000 rows
# (pid=30413) proces 26 has routed 700000 rows
# (pid=30412) proces 29 has routed 300000 rows
# (pid=30410) proces 27 has routed 600000 rows
# (pid=30409) proces 25 has routed 900000 rows
# (pid=30415) proces 28 has routed 500000 rows
# (pid=30413) proces 26 has routed 800000 rows
# (pid=30411) proces 24 has routed 1100000 rows
# (pid=30412) proces 29 has routed 400000 rows
# (pid=30410) proces 27 has routed 700000 rows
# (pid=30409) proces 25 has routed 1000000 rows
# (pid=30415) proces 28 has routed 600000 rows
# (pid=30411) proces 24 has routed 1200000 rows
# (pid=30413) proces 26 has routed 900000 rows
# (pid=30412) proces 29 has routed 500000 rows
# (pid=30410) proces 27 has routed 800000 rows
# (pid=30409) proces 25 has routed 1100000 rows
# (pid=30415) proces 28 has routed 700000 rows
# (pid=30413) proces 26 has routed 1000000 rows
# (pid=30411) proces 24 has routed 1300000 rows
# (pid=30410) proces 27 has routed 900000 rows
# (pid=30412) proces 29 has routed 600000 rows
# (pid=30409) proces 25 has routed 1200000 rows
# (pid=30415) proces 28 has routed 800000 rows
# (pid=30411) proces 24 has routed 1400000 rows
# (pid=30413) proces 26 has routed 1100000 rows
# (pid=30410) proces 27 has routed 1000000 rows
# (pid=30412) proces 29 has routed 700000 rows
# (pid=30409) proces 25 has routed 1300000 rows
# (pid=30415) proces 28 has routed 900000 rows
# (pid=30411) proces 24 has routed 1500000 rows
# (pid=30413) proces 26 has routed 1200000 rows
# (pid=30410) proces 27 has routed 1100000 rows
# (pid=30412) proces 29 has routed 800000 rows
# (pid=30409) proces 25 has routed 1400000 rows
# (pid=30415) proces 28 has routed 1000000 rows
# (pid=30411) proces 24 has routed 1600000 rows
# (pid=30413) proces 26 has routed 1300000 rows
# (pid=30410) proces 27 has routed 1200000 rows
# (pid=30412) proces 29 has routed 900000 rows
# (pid=30409) proces 25 has routed 1500000 rows
# (pid=30415) proces 28 has routed 1100000 rows
# (pid=30413) proces 26 has routed 1400000 rows
# (pid=30411) proces 24 has routed 1700000 rows
# (pid=30409) proces 25 has routed 1600000 rows
# (pid=30412) proces 29 has routed 1000000 rows
# (pid=30410) proces 27 has routed 1300000 rows
# (pid=30415) proces 28 has routed 1200000 rows
# (pid=30413) proces 26 has routed 1500000 rows
# (pid=30411) proces 24 has routed 1800000 rows
# (pid=30410) proces 27 has routed 1400000 rows
# (pid=30412) proces 29 has routed 1100000 rows
# (pid=30409) proces 25 has routed 1700000 rows
# (pid=30415) proces 28 has routed 1300000 rows
# (pid=30413) proces 26 has routed 1600000 rows
# (pid=30411) proces 24 has routed 1900000 rows
# (pid=30410) proces 27 has routed 1500000 rows
# (pid=30412) proces 29 has routed 1200000 rows
# (pid=30409) proces 25 has routed 1800000 rows
# (pid=30415) proces 28 has routed 1400000 rows
# (pid=30410) proces 27 has routed 1600000 rows
# (pid=30413) proces 26 has routed 1700000 rows
# (pid=30409) proces 25 has routed 1900000 rows
# (pid=30412) proces 29 has routed 1300000 rows
# (pid=30415) proces 28 has routed 1500000 rows
# (pid=30413) proces 26 has routed 1800000 rows
# (pid=30410) proces 27 has routed 1700000 rows
# (pid=30412) proces 29 has routed 1400000 rows
# (pid=30411) exit data routing process 24 .
# (pid=30415) proces 28 has routed 1600000 rows
# (pid=30413) proces 26 has routed 1900000 rows
# (pid=30410) proces 27 has routed 1800000 rows
# (pid=30412) proces 29 has routed 1500000 rows
# (pid=30409) exit data routing process 25 .
# (pid=30415) proces 28 has routed 1700000 rows
# (pid=30410) proces 27 has routed 1900000 rows
# (pid=30412) proces 29 has routed 1600000 rows
# (pid=30415) proces 28 has routed 1800000 rows
# (pid=30413) exit data routing process 26 .
# (pid=30412) proces 29 has routed 1700000 rows
# (pid=30415) proces 28 has routed 1900000 rows
# (pid=30412) proces 29 has routed 1800000 rows
# (pid=30410) exit data routing process 27 .
# (pid=30412) proces 29 has routed 1900000 rows
# = = = Finish Dump For Chunk(pid=30415) exit data routing process 28 .
#  18 to 23 = = =
# = = = TOTAL PROCESSED SO FAR: 48000000 ROWS. TIME SPENT: 628.2904281616211 SECONDS = = =
# reading chunk:  30
# (pid=30412) exit data routing process 29 .
# (pid=30415) enter data routing process 30 ..
# (pid=30415) proces 30 has routed 0 rows
# reading chunk:  31
# (pid=30412) enter data routing process 31 ..
# (pid=30415) proces 30 has routed 100000 rows
# (pid=30412) proces 31 has routed 0 rows
# reading chunk:  32
# (pid=30415) proces 30 has routed 200000 rows
# (pid=30410) enter data routing process 32 ..
# (pid=30412) proces 31 has routed 100000 rows
# (pid=30410) proces 32 has routed 0 rows
# reading chunk:  33
# (pid=30415) proces 30 has routed 300000 rows
# (pid=30412) proces 31 has routed 200000 rows
# (pid=30413) enter data routing process 33 ..
# (pid=30410) proces 32 has routed 100000 rows
# (pid=30413) proces 33 has routed 0 rows
# (pid=30415) proces 30 has routed 400000 rows
# (pid=30412) proces 31 has routed 300000 rows
# reading chunk:  34
# (pid=30410) proces 32 has routed 200000 rows
# (pid=30409) enter data routing process 34 ..
# (pid=30413) proces 33 has routed 100000 rows
# (pid=30415) proces 30 has routed 500000 rows
# (pid=30412) proces 31 has routed 400000 rows
# (pid=30409) proces 34 has routed 0 rows
# (pid=30410) proces 32 has routed 300000 rowsreading chunk:
#  35
# (pid=30413) proces 33 has routed 200000 rows
# = = = Process Dump For Chunk 24 to 29 = = =
# (pid=30415) proces 30 has routed 600000 rows
# (pid=30411) enter data routing process 35 ..
# (pid=30412) proces 31 has routed 500000 rows
# (pid=30409) proces 34 has routed 100000 rows
# (pid=30411) proces 35 has routed 0 rows
# (pid=30410) proces 32 has routed 400000 rows
# (pid=30413) proces 33 has routed 300000 rows
# (pid=30415) proces 30 has routed 700000 rows
# (pid=30409) proces 34 has routed 200000 rows
# (pid=30412) proces 31 has routed 600000 rows
# (pid=30411) proces 35 has routed 100000 rows
# (pid=30410) proces 32 has routed 500000 rows
# (pid=30413) proces 33 has routed 400000 rows
# (pid=30415) proces 30 has routed 800000 rows
# (pid=30409) proces 34 has routed 300000 rows
# (pid=30412) proces 31 has routed 700000 rows
# (pid=30411) proces 35 has routed 200000 rows
# (pid=30410) proces 32 has routed 600000 rows
# (pid=30413) proces 33 has routed 500000 rows
# (pid=30409) proces 34 has routed 400000 rows
# (pid=30412) proces 31 has routed 800000 rows
# (pid=30415) proces 30 has routed 900000 rows
# (pid=30411) proces 35 has routed 300000 rows
# (pid=30410) proces 32 has routed 700000 rows
# (pid=30413) proces 33 has routed 600000 rows
# (pid=30409) proces 34 has routed 500000 rows
# (pid=30415) proces 30 has routed 1000000 rows
# (pid=30412) proces 31 has routed 900000 rows
# (pid=30411) proces 35 has routed 400000 rows
# (pid=30410) proces 32 has routed 800000 rows
# (pid=30413) proces 33 has routed 700000 rows
# (pid=30409) proces 34 has routed 600000 rows
# (pid=30415) proces 30 has routed 1100000 rows
# (pid=30412) proces 31 has routed 1000000 rows
# (pid=30411) proces 35 has routed 500000 rows
# (pid=30410) proces 32 has routed 900000 rows
# (pid=30413) proces 33 has routed 800000 rows
# (pid=30412) proces 31 has routed 1100000 rows
# (pid=30409) proces 34 has routed 700000 rows
# (pid=30415) proces 30 has routed 1200000 rows
# (pid=30411) proces 35 has routed 600000 rows
# (pid=30410) proces 32 has routed 1000000 rows
# (pid=30413) proces 33 has routed 900000 rows
# (pid=30409) proces 34 has routed 800000 rows
# (pid=30412) proces 31 has routed 1200000 rows
# (pid=30415) proces 30 has routed 1300000 rows
# (pid=30410) proces 32 has routed 1100000 rows
# (pid=30411) proces 35 has routed 700000 rows
# (pid=30413) proces 33 has routed 1000000 rows
# (pid=30412) proces 31 has routed 1300000 rows
# (pid=30409) proces 34 has routed 900000 rows
# (pid=30415) proces 30 has routed 1400000 rows
# (pid=30411) proces 35 has routed 800000 rows
# (pid=30410) proces 32 has routed 1200000 rows
# (pid=30413) proces 33 has routed 1100000 rows
# (pid=30412) proces 31 has routed 1400000 rows
# (pid=30409) proces 34 has routed 1000000 rows
# (pid=30415) proces 30 has routed 1500000 rows
# (pid=30411) proces 35 has routed 900000 rows
# (pid=30410) proces 32 has routed 1300000 rows
# (pid=30409) proces 34 has routed 1100000 rows
# (pid=30413) proces 33 has routed 1200000 rows
# (pid=30412) proces 31 has routed 1500000 rows
# (pid=30415) proces 30 has routed 1600000 rows
# (pid=30411) proces 35 has routed 1000000 rows
# (pid=30410) proces 32 has routed 1400000 rows
# (pid=30413) proces 33 has routed 1300000 rows
# (pid=30409) proces 34 has routed 1200000 rows
# (pid=30412) proces 31 has routed 1600000 rows
# (pid=30411) proces 35 has routed 1100000 rows
# (pid=30415) proces 30 has routed 1700000 rows
# (pid=30410) proces 32 has routed 1500000 rows
# (pid=30413) proces 33 has routed 1400000 rows
# (pid=30409) proces 34 has routed 1300000 rows
# (pid=30412) proces 31 has routed 1700000 rows
# (pid=30415) proces 30 has routed 1800000 rows
# (pid=30411) proces 35 has routed 1200000 rows
# (pid=30410) proces 32 has routed 1600000 rows
# (pid=30409) proces 34 has routed 1400000 rows
# (pid=30412) proces 31 has routed 1800000 rows
# (pid=30413) proces 33 has routed 1500000 rows
# (pid=30411) proces 35 has routed 1300000 rows
# (pid=30410) proces 32 has routed 1700000 rows
# (pid=30415) proces 30 has routed 1900000 rows
# (pid=30413) proces 33 has routed 1600000 rows
# (pid=30409) proces 34 has routed 1500000 rows
# (pid=30411) proces 35 has routed 1400000 rows
# (pid=30410) proces 32 has routed 1800000 rows
# (pid=30412) proces 31 has routed 1900000 rows
# (pid=30413) proces 33 has routed 1700000 rows
# (pid=30409) proces 34 has routed 1600000 rows
# (pid=30411) proces 35 has routed 1500000 rows
# (pid=30410) proces 32 has routed 1900000 rows
# (pid=30415) exit data routing process 30 .
# (pid=30413) proces 33 has routed 1800000 rows
# (pid=30409) proces 34 has routed 1700000 rows
# (pid=30411) proces 35 has routed 1600000 rows
# (pid=30412) exit data routing process 31 .
# (pid=30409) proces 34 has routed 1800000 rows
# (pid=30411) proces 35 has routed 1700000 rows
# (pid=30413) proces 33 has routed 1900000 rows
# (pid=30410) exit data routing process 32 .
# (pid=30411) proces 35 has routed 1800000 rows
# (pid=30409) proces 34 has routed 1900000 rows
# = = = Finish Dump For Chunk 24 to 29 = = =
# = = = TOTAL PROCESSED SO FAR: 60000000 ROWS. TIME SPENT: 758.7076487541199 SECONDS = = =
# (pid=30411) proces 35 has routed 1900000 rows
# (pid=30413) exit data routing process 33 .
# (pid=30409) exit data routing process 34 .
# reading chunk:  36
# (pid=30411) exit data routing process 35 .
# (pid=30409) enter data routing process 36 ..
# (pid=30409) proces 36 has routed 0 rows
# reading chunk:  37
# (pid=30409) proces 36 has routed 100000 rows
# (pid=30411) enter data routing process 37 ..
# (pid=30411) proces 37 has routed 0 rows
# reading chunk:  38
# (pid=30409) proces 36 has routed 200000 rows
# (pid=30411) proces 37 has routed 100000 rows
# (pid=30413) enter data routing process 38 ..
# (pid=30413) proces 38 has routed 0 rows
# (pid=30409) proces 36 has routed 300000 rows
# reading chunk:  39
# (pid=30411) proces 37 has routed 200000 rows
# (pid=30410) enter data routing process 39 ..
# (pid=30413) proces 38 has routed 100000 rows
# (pid=30409) proces 36 has routed 400000 rows
# (pid=30410) proces 39 has routed 0 rows
# (pid=30411) proces 37 has routed 300000 rows
# reading chunk:  40
# (pid=30413) proces 38 has routed 200000 rows
# (pid=30409) proces 36 has routed 500000 rows
# (pid=30412) enter data routing process 40 ..
# (pid=30410) proces 39 has routed 100000 rows
# (pid=30412) proces 40 has routed 0 rows
# (pid=30411) proces 37 has routed 400000 rows
# reading chunk:  41
# (pid=30413) proces 38 has routed 300000 rows
# (pid=30410) proces 39 has routed 200000 rows
# (pid=30409) proces 36 has routed 600000 rows
# = = = Process Dump For Chunk 30 to 35 = = =
# (pid=30412) proces 40 has routed 100000 rows
# (pid=30415) enter data routing process 41 ..
# (pid=30411) proces 37 has routed 500000 rows
# (pid=30415) proces 41 has routed 0 rows
# (pid=30413) proces 38 has routed 400000 rows
# (pid=30410) proces 39 has routed 300000 rows
# (pid=30409) proces 36 has routed 700000 rows
# (pid=30412) proces 40 has routed 200000 rows
# (pid=30411) proces 37 has routed 600000 rows
# (pid=30415) proces 41 has routed 100000 rows
# (pid=30413) proces 38 has routed 500000 rows
# (pid=30410) proces 39 has routed 400000 rows
# (pid=30409) proces 36 has routed 800000 rows
# (pid=30412) proces 40 has routed 300000 rows
# (pid=30411) proces 37 has routed 700000 rows
# (pid=30415) proces 41 has routed 200000 rows
# (pid=30413) proces 38 has routed 600000 rows
# (pid=30409) proces 36 has routed 900000 rows
# (pid=30410) proces 39 has routed 500000 rows
# (pid=30412) proces 40 has routed 400000 rows
# (pid=30411) proces 37 has routed 800000 rows
# (pid=30415) proces 41 has routed 300000 rows
# (pid=30413) proces 38 has routed 700000 rows
# (pid=30410) proces 39 has routed 600000 rows
# (pid=30409) proces 36 has routed 1000000 rows
# (pid=30412) proces 40 has routed 500000 rows
# (pid=30411) proces 37 has routed 900000 rows
# (pid=30415) proces 41 has routed 400000 rows
# (pid=30413) proces 38 has routed 800000 rows
# (pid=30410) proces 39 has routed 700000 rows
# (pid=30409) proces 36 has routed 1100000 rows
# (pid=30412) proces 40 has routed 600000 rows
# (pid=30411) proces 37 has routed 1000000 rows
# (pid=30415) proces 41 has routed 500000 rows
# (pid=30413) proces 38 has routed 900000 rows
# (pid=30410) proces 39 has routed 800000 rows
# (pid=30412) proces 40 has routed 700000 rows
# (pid=30409) proces 36 has routed 1200000 rows
# (pid=30411) proces 37 has routed 1100000 rows
# (pid=30415) proces 41 has routed 600000 rows
# (pid=30413) proces 38 has routed 1000000 rows
# (pid=30410) proces 39 has routed 900000 rows
# (pid=30409) proces 36 has routed 1300000 rows
# (pid=30412) proces 40 has routed 800000 rows
# (pid=30415) proces 41 has routed 700000 rows
# (pid=30411) proces 37 has routed 1200000 rows
# (pid=30413) proces 38 has routed 1100000 rows
# (pid=30409) proces 36 has routed 1400000 rows
# (pid=30410) proces 39 has routed 1000000 rows
# (pid=30412) proces 40 has routed 900000 rows
# (pid=30411) proces 37 has routed 1300000 rows
# (pid=30415) proces 41 has routed 800000 rows
# (pid=30413) proces 38 has routed 1200000 rows
# (pid=30409) proces 36 has routed 1500000 rows
# (pid=30410) proces 39 has routed 1100000 rows
# (pid=30412) proces 40 has routed 1000000 rows
# (pid=30411) proces 37 has routed 1400000 rows
# (pid=30415) proces 41 has routed 900000 rows
# (pid=30413) proces 38 has routed 1300000 rows
# (pid=30412) proces 40 has routed 1100000 rows
# (pid=30410) proces 39 has routed 1200000 rows
# (pid=30409) proces 36 has routed 1600000 rows
# (pid=30411) proces 37 has routed 1500000 rows
# (pid=30415) proces 41 has routed 1000000 rows
# (pid=30413) proces 38 has routed 1400000 rows
# (pid=30410) proces 39 has routed 1300000 rows
# (pid=30409) proces 36 has routed 1700000 rows
# (pid=30412) proces 40 has routed 1200000 rows
# (pid=30415) proces 41 has routed 1100000 rows
# (pid=30411) proces 37 has routed 1600000 rows
# (pid=30413) proces 38 has routed 1500000 rows
# (pid=30410) proces 39 has routed 1400000 rows
# (pid=30409) proces 36 has routed 1800000 rows
# (pid=30412) proces 40 has routed 1300000 rows
# (pid=30411) proces 37 has routed 1700000 rows
# (pid=30415) proces 41 has routed 1200000 rows
# (pid=30410) proces 39 has routed 1500000 rows
# (pid=30409) proces 36 has routed 1900000 rows
# (pid=30413) proces 38 has routed 1600000 rows
# (pid=30412) proces 40 has routed 1400000 rows
# (pid=30411) proces 37 has routed 1800000 rows
# (pid=30415) proces 41 has routed 1300000 rows
# (pid=30413) proces 38 has routed 1700000 rows
# (pid=30412) proces 40 has routed 1500000 rows
# (pid=30410) proces 39 has routed 1600000 rows
# (pid=30411) proces 37 has routed 1900000 rows
# (pid=30415) proces 41 has routed 1400000 rows
# (pid=30413) proces 38 has routed 1800000 rows
# (pid=30410) proces 39 has routed 1700000 rows
# (pid=30412) proces 40 has routed 1600000 rows
# (pid=30409) exit data routing process 36 .
# (pid=30415) proces 41 has routed 1500000 rows
# (pid=30413) proces 38 has routed 1900000 rows
# (pid=30410) proces 39 has routed 1800000 rows
# (pid=30412) proces 40 has routed 1700000 rows
# (pid=30415) proces 41 has routed 1600000 rows
# (pid=30411) exit data routing process 37 .
# (pid=30412) proces 40 has routed 1800000 rows
# (pid=30410) proces 39 has routed 1900000 rows
# (pid=30415) proces 41 has routed 1700000 rows
# (pid=30412) proces 40 has routed 1900000 rows
# (pid=30413) exit data routing process 38 .
# (pid=30415) proces 41 has routed 1800000 rows
# (pid=30410) exit data routing process 39 .
# (pid=30415) proces 41 has routed 1900000 rows
# (pid=30412) exit data routing process 40 .
# = = = Finish Dump For Chunk 30 to 35 = = =
# = = = TOTAL PROCESSED SO FAR: 72000000 ROWS. TIME SPENT: 894.1110694408417 SECONDS = = =
# (pid=30415) exit data routing process 41 .
# reading chunk:  42
# (pid=30415) enter data routing process 42 ..
# (pid=30415) proces 42 has routed 0 rows
# reading chunk:  43
# (pid=30415) proces 42 has routed 100000 rows
# (pid=30412) enter data routing process 43 ..
# (pid=30412) proces 43 has routed 0 rows
# reading chunk:  44
# (pid=30415) proces 42 has routed 200000 rows
# (pid=30412) proces 43 has routed 100000 rows
# (pid=30410) enter data routing process 44 ..
# (pid=30410) proces 44 has routed 0 rows
# (pid=30415) proces 42 has routed 300000 rows
# reading chunk:  45
# (pid=30412) proces 43 has routed 200000 rows
# (pid=30410) proces 44 has routed 100000 rows
# (pid=30413) enter data routing process 45 ..
# (pid=30415) proces 42 has routed 400000 rows
# (pid=30413) proces 45 has routed 0 rows
# (pid=30412) proces 43 has routed 300000 rows
# reading chunk:  46
# (pid=30410) proces 44 has routed 200000 rows
# (pid=30415) proces 42 has routed 500000 rows
# (pid=30413) proces 45 has routed 100000 rows
# (pid=30411) enter data routing process 46 ..
# (pid=30412) proces 43 has routed 400000 rows
# (pid=30411) proces 46 has routed 0 rows
# (pid=30410) proces 44 has routed 300000 rows
# reading chunk:  47
# (pid=30415) proces 42 has routed 600000 rows
# (pid=30413) proces 45 has routed 200000 rows
# (pid=30412) proces 43 has routed 500000 rows
# = = = Process Dump For Chunk 36 to 41 = = =
# (pid=30409) enter data routing process 47 ..
# (pid=30411) proces 46 has routed 100000 rows
# (pid=30410) proces 44 has routed 400000 rows
# (pid=30409) proces 47 has routed 0 rows
# (pid=30415) proces 42 has routed 700000 rows
# (pid=30413) proces 45 has routed 300000 rows
# (pid=30412) proces 43 has routed 600000 rows
# (pid=30411) proces 46 has routed 200000 rows
# (pid=30410) proces 44 has routed 500000 rows
# (pid=30409) proces 47 has routed 100000 rows
# (pid=30415) proces 42 has routed 800000 rows
# (pid=30413) proces 45 has routed 400000 rows
# (pid=30412) proces 43 has routed 700000 rows
# (pid=30411) proces 46 has routed 300000 rows
# (pid=30410) proces 44 has routed 600000 rows
# (pid=30409) proces 47 has routed 200000 rows
# (pid=30415) proces 42 has routed 900000 rows
# (pid=30413) proces 45 has routed 500000 rows
# (pid=30412) proces 43 has routed 800000 rows
# (pid=30411) proces 46 has routed 400000 rows
# (pid=30410) proces 44 has routed 700000 rows
# (pid=30409) proces 47 has routed 300000 rows
# (pid=30415) proces 42 has routed 1000000 rows
# (pid=30412) proces 43 has routed 900000 rows
# (pid=30413) proces 45 has routed 600000 rows
# (pid=30411) proces 46 has routed 500000 rows
# (pid=30409) proces 47 has routed 400000 rows
# (pid=30410) proces 44 has routed 800000 rows
# (pid=30415) proces 42 has routed 1100000 rows
# (pid=30412) proces 43 has routed 1000000 rows
# (pid=30413) proces 45 has routed 700000 rows
# (pid=30411) proces 46 has routed 600000 rows
# (pid=30409) proces 47 has routed 500000 rows
# (pid=30410) proces 44 has routed 900000 rows
# (pid=30415) proces 42 has routed 1200000 rows
# (pid=30412) proces 43 has routed 1100000 rows
# (pid=30413) proces 45 has routed 800000 rows
# (pid=30411) proces 46 has routed 700000 rows
# (pid=30410) proces 44 has routed 1000000 rows
# (pid=30409) proces 47 has routed 600000 rows
# (pid=30415) proces 42 has routed 1300000 rows
# (pid=30412) proces 43 has routed 1200000 rows
# (pid=30413) proces 45 has routed 900000 rows
# (pid=30411) proces 46 has routed 800000 rows
# (pid=30409) proces 47 has routed 700000 rows
# (pid=30410) proces 44 has routed 1100000 rows
# (pid=30415) proces 42 has routed 1400000 rows
# (pid=30412) proces 43 has routed 1300000 rows
# (pid=30413) proces 45 has routed 1000000 rows
# (pid=30411) proces 46 has routed 900000 rows
# (pid=30409) proces 47 has routed 800000 rows
# (pid=30410) proces 44 has routed 1200000 rows
# (pid=30415) proces 42 has routed 1500000 rows
# (pid=30412) proces 43 has routed 1400000 rows
# (pid=30413) proces 45 has routed 1100000 rows
# (pid=30411) proces 46 has routed 1000000 rows
# (pid=30409) proces 47 has routed 900000 rows
# (pid=30415) proces 42 has routed 1600000 rows
# (pid=30410) proces 44 has routed 1300000 rows
# (pid=30412) proces 43 has routed 1500000 rows
# (pid=30413) proces 45 has routed 1200000 rows
# (pid=30411) proces 46 has routed 1100000 rows
# (pid=30409) proces 47 has routed 1000000 rows
# (pid=30410) proces 44 has routed 1400000 rows
# (pid=30415) proces 42 has routed 1700000 rows
# (pid=30412) proces 43 has routed 1600000 rows
# (pid=30411) proces 46 has routed 1200000 rows
# (pid=30413) proces 45 has routed 1300000 rows
# (pid=30409) proces 47 has routed 1100000 rows
# (pid=30410) proces 44 has routed 1500000 rows
# (pid=30415) proces 42 has routed 1800000 rows
# ...
# (pid=30412) proces 295 has routed 1700000 rows
# (pid=30411) proces 298 has routed 1300000 rows
# (pid=30409) proces 299 has routed 1200000 rows
# (pid=30415) proces 294 has routed 1900000 rows
# (pid=30410) proces 296 has routed 1600000 rows
# (pid=30413) proces 297 has routed 1500000 rows
# (pid=30411) proces 298 has routed 1400000 rows
# (pid=30412) proces 295 has routed 1800000 rows
# (pid=30409) proces 299 has routed 1300000 rows
# (pid=30410) proces 296 has routed 1700000 rows
# (pid=30413) proces 297 has routed 1600000 rows
# (pid=30411) proces 298 has routed 1500000 rows
# (pid=30412) proces 295 has routed 1900000 rows
# (pid=30409) proces 299 has routed 1400000 rows
# (pid=30415) exit data routing process 294 .
# (pid=30410) proces 296 has routed 1800000 rows
# (pid=30413) proces 297 has routed 1700000 rows
# (pid=30411) proces 298 has routed 1600000 rows
# (pid=30409) proces 299 has routed 1500000 rows
# (pid=30410) proces 296 has routed 1900000 rows
# (pid=30413) proces 297 has routed 1800000 rows
# (pid=30411) proces 298 has routed 1700000 rows
# (pid=30409) proces 299 has routed 1600000 rows
# (pid=30412) exit data routing process 295 .
# (pid=30413) proces 297 has routed 1900000 rows
# (pid=30411) proces 298 has routed 1800000 rows
# (pid=30409) proces 299 has routed 1700000 rows
# (pid=30410) exit data routing process 296 .
# (pid=30411) proces 298 has routed 1900000 rows
# (pid=30409) proces 299 has routed 1800000 rows
# (pid=30409) proces 299 has routed 1900000 rows
# (pid=30413) exit data routing process 297 .
# (pid=30411) exit data routing process 298 .
# = = = Finish Dump For Chunk 288 to 293 = = =
# = = = TOTAL PROCESSED SO FAR: 588000000 ROWS. TIME SPENT: 6831.362502813339 SECONDS = = =
# reading chunk:  300
# = = = Process Dump For Last Few Chunks = = =
# (pid=30411) enter data routing process 300 ..
# (pid=30411) proces 300 has routed 0 rows
# (pid=30411) exit data routing process 300 .
# (pid=30409) exit data routing process 299 .
# = = = Start Merging the Epochs = = =
# (pid=30412) 2021-07-01 16:47:32,688 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# (pid=30415) 2021-07-01 16:47:32,685 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# (pid=30409) 2021-07-01 16:47:32,664 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# (pid=30411) 2021-07-01 16:47:32,678 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# (pid=30413) 2021-07-01 16:47:32,682 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# (pid=30410) 2021-07-01 16:47:32,707 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# (pid=30410) process 3 pid 224  len parquets (epochs): 51
# (pid=30412) process 4 pid 303  len parquets (epochs): 51
# (pid=30415) process 5 pid 376  len parquets (epochs): 51
# (pid=30411) process 1 pid 82  len parquets (epochs): 51
# (pid=30413) process 2 pid 155  len parquets (epochs): 51
# (pid=30412) process 4 pid 304  len parquets (epochs): 51
# (pid=30415) process 5 pid 377  len parquets (epochs): 51
# (pid=30413) process 2 pid 156  len parquets (epochs): 51
# (pid=30411) process 1 pid 85  len parquets (epochs): 51
# (pid=30409) process 0 pid 11  len parquets (epochs): 51
# (pid=30415) process 5 pid 378  len parquets (epochs):
# (pid=30415) 51
# (pid=30412) process 4 pid 307  len parquets (epochs): 51
# (pid=30413) process 2 pid 161  len parquets (epochs): 51
# (pid=30411) process 1 pid 86  len parquets (epochs): 51
# (pid=30410) process 3 pid 233  len parquets (epochs): 51
# (pid=30415) process 5 pid 383  len parquets (epochs): 51
# (pid=30412) process 4 pid 308  len parquets (epochs): 51
# (pid=30413) process 2 pid 162  len parquets (epochs): 51
# (pid=30411) process 1 pid 89  len parquets (epochs): 51
# (pid=30415) process 5 pid 384  len parquets (epochs): 51
# (pid=30412) process 4 pid 311  len parquets (epochs): 51
# (pid=30413) process 2 pid 165  len parquets (epochs): 51
# (pid=30411) process 1 pid 90  len parquets (epochs): 51
# (pid=30415) process 5 pid 387  len parquets (epochs): 51
# (pid=30412) process 4 pid 312  len parquets (epochs): 51
# (pid=30411) process 1 pid 91  len parquets (epochs): 51
# (pid=30413) process 2 pid 166  len parquets (epochs): 51
# (pid=30409) process 0 pid 12  len parquets (epochs): 51
# (pid=30415) process 5 pid 388  len parquets (epochs): 51
# (pid=30412) process 4 pid 313  len parquets (epochs): 51
# (pid=30410) process 3 pid 234  len parquets (epochs): 51
# (pid=30411) process 1 pid 92  len parquets (epochs): 51
# (pid=30413) process 2 pid 167  len parquets (epochs): 51
# (pid=30415) process 5 pid 389  len parquets (epochs): 51
# (pid=30412) process 4 pid 314  len parquets (epochs): 51
# (pid=30413) process 2 pid 168  len parquets (epochs): 51
# (pid=30411) process 1 pid 97  len parquets (epochs): 51
# (pid=30415) process 5 pid 390  len parquets (epochs): 51
# (pid=30412) process 4 pid 319  len parquets (epochs): 51
# (pid=30413) process 2 pid 171  len parquets (epochs): 51
# (pid=30411) process 1 pid 98  len parquets (epochs): 51
# (pid=30415) process 5 pid 393  len parquets (epochs): 51
# (pid=30412) process 4 pid 320  len parquets (epochs): 51
# (pid=30411) process 1 pid 101  len parquets (epochs): 51
# (pid=30413) process 2 pid 172  len parquets (epochs): 51
# (pid=30409) process 0 pid 13  len parquets (epochs): 51
# (pid=30415) process 5 pid 394  len parquets (epochs): 51
# (pid=30410) process 3 pid 235  len parquets (epochs): 51
# (pid=30412) process 4 pid 323  len parquets (epochs): 51
# (pid=30411) process 1 pid 102  len parquets (epochs): 51
# (pid=30413) process 2 pid 175  len parquets (epochs): 51
# (pid=30412) process 4 pid 324  len parquets (epochs): 51
# (pid=30415) process 5 pid 397  len parquets (epochs): 51
# (pid=30411) process 1 pid 103  len parquets (epochs): 51
# (pid=30413) process 2 pid 176  len parquets (epochs): 51
# (pid=30412) process 4 pid 325  len parquets (epochs): 51
# (pid=30415) process 5 pid 398  len parquets (epochs): 51
# (pid=30411) process 1 pid 104  len parquets (epochs): 51
# (pid=30413) process 2 pid 177  len parquets (epochs): 51
# (pid=30412) process 4 pid 326  len parquets (epochs): 51
# (pid=30415) process 5 pid 399  len parquets (epochs): 51
# (pid=30409) process 0 pid 14  len parquets (epochs): 51
# (pid=30411) process 1 pid 107  len parquets (epochs): 51
# (pid=30410) process 3 pid 236  len parquets (epochs): 51
# (pid=30413) process 2 pid 178  len parquets (epochs): 51
# (pid=30412) process 4 pid 329  len parquets (epochs): 51
# (pid=30415) process 5 pid 400  len parquets (epochs): 51
# (pid=30411) process 1 pid 108  len parquets (epochs): 51
# (pid=30413) process 2 pid 185  len parquets (epochs): 51
# (pid=30412) process 4 pid 330  len parquets (epochs): 51
# (pid=30415) process 5 pid 407  len parquets (epochs): 51
# (pid=30411) process 1 pid 111  len parquets (epochs): 51
# (pid=30413) process 2 pid 186  len parquets (epochs): 51
# (pid=30412) process 4 pid 333  len parquets (epochs): 51
# (pid=30415) process 5 pid 408  len parquets (epochs): 51
# (pid=30411) process 1 pid 112  len parquets (epochs): 51
# (pid=30412) process 4 pid 334  len parquets (epochs): 51
# (pid=30413) process 2 pid 189  len parquets (epochs): 51
# (pid=30409) process 0 pid 17  len parquets (epochs): 51
# (pid=30415) process 5 pid 411  len parquets (epochs): 51
# (pid=30410) process 3 pid 239  len parquets (epochs): 51
# (pid=30411) process 1 pid 113  len parquets (epochs): 51
# (pid=30412) process 4 pid 335  len parquets (epochs): 51
# (pid=30413) process 2 pid 190  len parquets (epochs): 51
# (pid=30415) process 5 pid 412  len parquets (epochs): 51
# (pid=30411) process 1 pid 114  len parquets (epochs): 51
# (pid=30413) process 2 pid 191  len parquets (epochs): 51
# (pid=30412) process 4 pid 336  len parquets (epochs): 51
# (pid=30415) process 5 pid 413  len parquets (epochs): 51
# (pid=30413) process 2 pid 192  len parquets (epochs): 51
# (pid=30415) process 5 pid 414  len parquets (epochs): 51
# (pid=30409) process 0 pid 18  len parquets (epochs): 51
# (pid=30410) process 3 pid 240  len parquets (epochs): 51
# (pid=30413) process 2 pid 195  len parquets (epochs): 51
# (pid=30411) process 1 pid 121  len parquets (epochs): 51
# (pid=30415) process 5 pid 417  len parquets (epochs): 51
# (pid=30412) process 4 pid 343  len parquets (epochs): 51
# (pid=30413) process 2 pid 196  len parquets (epochs): 51
# (pid=30415) process 5 pid 418  len parquets (epochs): 51
# (pid=30413) process 2 pid 199  len parquets (epochs): 51
# (pid=30415) process 5 pid 421  len parquets (epochs): 51
# (pid=30413) process 2 pid 200  len parquets (epochs): 51
# (pid=30410) process 3 pid 241  len parquets (epochs): 51
# (pid=30409) process 0 pid 19  len parquets (epochs): 51
# (pid=30411) process 1 pid 122  len parquets (epochs): 51
# (pid=30415) process 5 pid 422  len parquets (epochs): 51
# (pid=30412) process 4 pid 344  len parquets (epochs): 51
# (pid=30413) process 2 pid 201  len parquets (epochs): 51
# (pid=30415) process 5 pid 423  len parquets (epochs): 51
# (pid=30413) process 2 pid 202  len parquets (epochs): 51
# (pid=30415) process 5 pid 424  len parquets (epochs): 51
# (pid=30413) process 2 pid 207  len parquets (epochs): 51
# (pid=30410) process 3 pid 242  len parquets (epochs): 51
# (pid=30409) process 0 pid 20  len parquets (epochs): 51
# (pid=30411) process 1 pid 123  len parquets (epochs): 51
# (pid=30412) process 4 pid 345  len parquets (epochs): 51
# (pid=30415) process 5 pid 429  len parquets (epochs): 51
# (pid=30413) process 2 pid 208  len parquets (epochs): 51
# (pid=30415) process 5 pid 430  len parquets (epochs): 51
# (pid=30413) process 2 pid 211  len parquets (epochs): 51
# (pid=30410) process 3 pid 251  len parquets (epochs): 51
# (pid=30409) process 0 pid 29  len parquets (epochs): 51
# (pid=30413) process 2 pid 212  len parquets (epochs): 51
# (pid=30415) process 5 pid 433  len parquets (epochs): 51
# (pid=30410) process 3 pid 252  len parquets (epochs): 51
# (pid=30409) process 0 pid 30  len parquets (epochs): 51
# (pid=30412) process 4 pid 346  len parquets (epochs): 51
# (pid=30411) process 1 pid 124  len parquets (epochs): 51
# (pid=30413) process 2 pid 213  len parquets (epochs): 51
# (pid=30415) process 5 pid 434  len parquets (epochs): 51
# (pid=30409) process 0 pid 33  len parquets (epochs): 51
# (pid=30410) process 3 pid 255  len parquets (epochs): 51
# (pid=30413) process 2 pid 214  len parquets (epochs): 51
# (pid=30415) process 5 pid 435  len parquets (epochs): 51
# (pid=30409) process 0 pid 34  len parquets (epochs): 51
# (pid=30410) process 3 pid 256  len parquets (epochs): 51
# (pid=30415) process 5 pid 436  len parquets (epochs): 51
# (pid=30413) process 2 pid 217  len parquets (epochs): 51
# (pid=30410) process 3 pid 257  len parquets (epochs): 51
# (pid=30409) process 0 pid 35  len parquets (epochs): 51
# (pid=30415) process 5 pid 439  len parquets (epochs): 51
# (pid=30413) process 2 pid 218  len parquets (epochs): 51
# (pid=30410) process 3 pid 258  len parquets (epochs): 51
# (pid=30409) process 0 pid 36  len parquets (epochs): 51
# (pid=30411) process 1 pid 127  len parquets (epochs): 51
# (pid=30412) process 4 pid 349  len parquets (epochs): 51
# (pid=30413) process 2 pid 221  len parquets (epochs): 51
# (pid=30415) process 5 pid 440  len parquets (epochs): 51
# (pid=30410) process 3 pid 261  len parquets (epochs): 51
# (pid=30409) process 0 pid 39  len parquets (epochs): 51
# (pid=30413) process 2 pid 222  len parquets (epochs): 51
# (pid=30410) process 3 pid 262  len parquets (epochs): 51
# (pid=30415) process 5 pid 443  len parquets (epochs): 51
# (pid=30409) process 0 pid 40  len parquets (epochs): 51
# (pid=30413) process 2 pid 223  len parquets (epochs): 51
# (pid=30413) exit merge process 2
# (pid=30415) process 5 pid 444  len parquets (epochs): 51
# (pid=30410) process 3 pid 265  len parquets (epochs): 51
# (pid=30409) process 0 pid 43  len parquets (epochs): 51
# (pid=30411) process 1 pid 128  len parquets (epochs): 51
# (pid=30412) process 4 pid 350  len parquets (epochs): 51
# (pid=30415) process 5 pid 445  len parquets (epochs): 51
# (pid=30410) process 3 pid 266  len parquets (epochs): 51
# (pid=30409) process 0 pid 44  len parquets (epochs): 51
# (pid=30415) process 5 pid 446  len parquets (epochs): 51
# (pid=30415) exit merge process 5
# (pid=30410) process 3 pid 267  len parquets (epochs): 51
# (pid=30409) process 0 pid 45  len parquets (epochs): 51
# (pid=30410) process 3 pid 268  len parquets (epochs): 51
# (pid=30409) process 0 pid 46  len parquets (epochs): 51
# (pid=30409) process 0 pid 51  len parquets (epochs): 51
# (pid=30410) process 3 pid 273  len parquets (epochs): 51
# (pid=30411) process 1 pid 129  len parquets (epochs): 51
# (pid=30412) process 4 pid 351  len parquets (epochs): 51
# (pid=30409) process 0 pid 52  len parquets (epochs): 51
# (pid=30410) process 3 pid 274  len parquets (epochs): 51
# (pid=30409) process 0 pid 55  len parquets (epochs): 51
# (pid=30410) process 3 pid 277  len parquets (epochs): 51
# (pid=30409) process 0 pid 56  len parquets (epochs): 51
# (pid=30410) process 3 pid 278  len parquets (epochs): 51
# (pid=30411) process 1 pid 130  len parquets (epochs): 51
# (pid=30412) process 4 pid 352  len parquets (epochs): 51
# (pid=30409) process 0 pid 57  len parquets (epochs): 51
# (pid=30410) process 3 pid 279  len parquets (epochs): 51
# (pid=30411) process 1 pid 139  len parquets (epochs): 51
# (pid=30409) process 0 pid 58  len parquets (epochs): 51
# (pid=30410) process 3 pid 280  len parquets (epochs): 51
# (pid=30412) process 4 pid 361  len parquets (epochs): 51
# (pid=30409) process 0 pid 61  len parquets (epochs): 51
# (pid=30411) process 1 pid 140  len parquets (epochs): 51
# (pid=30410) process 3 pid 283  len parquets (epochs): 51
# (pid=30412) process 4 pid 362  len parquets (epochs): 51
# (pid=30411) process 1 pid 143  len parquets (epochs): 51
# (pid=30409) process 0 pid 62  len parquets (epochs): 51
# (pid=30410) process 3 pid 284  len parquets (epochs): 51
# (pid=30412) process 4 pid 365  len parquets (epochs): 51
# (pid=30411) process 1 pid 144  len parquets (epochs): 51
# (pid=30409) process 0 pid 65  len parquets (epochs): 51
# (pid=30412) process 4 pid 366  len parquets (epochs): 51
# (pid=30410) process 3 pid 287  len parquets (epochs): 51
# (pid=30411) process 1 pid 145  len parquets (epochs): 51
# (pid=30409) process 0 pid 66  len parquets (epochs): 51
# (pid=30412) process 4 pid 367  len parquets (epochs): 51
# (pid=30410) process 3 pid 288  len parquets (epochs): 51
# (pid=30411) process 1 pid 146  len parquets (epochs): 51
# (pid=30409) process 0 pid 67  len parquets (epochs): 51
# (pid=30412) process 4 pid 368  len parquets (epochs): 51
# (pid=30410) process 3 pid 289  len parquets (epochs): 51
# (pid=30411) process 1 pid 149  len parquets (epochs): 51
# (pid=30412) process 4 pid 371  len parquets (epochs): 51
# (pid=30409) process 0 pid 68  len parquets (epochs): 51
# (pid=30410) process 3 pid 290  len parquets (epochs): 51
# (pid=30411) process 1 pid 150  len parquets (epochs): 51
# (pid=30409) process 0 pid 75  len parquets (epochs): 51
# (pid=30412) process 4 pid 372  len parquets (epochs): 51
# (pid=30410) process 3 pid 297  len parquets (epochs): 51
# (pid=30411) process 1 pid 153  len parquets (epochs): 51
# (pid=30412) process 4 pid 375  len parquets (epochs): 51
# (pid=30409) process 0 pid 76  len parquets (epochs): 51
# (pid=30412) exit merge process 4
# (pid=30410) process 3 pid 298  len parquets (epochs): 51
# (pid=30411) process 1 pid 154  len parquets (epochs): 51
# (pid=30409) process 0 pid 79  len parquets (epochs): 51
# (pid=30411) exit merge process 1
# (pid=30410) process 3 pid 301  len parquets (epochs): 51
# (pid=30409) process 0 pid 80  len parquets (epochs): 51
# (pid=30410) process 3 pid 302  len parquets (epochs): 51
# (pid=30410) exit merge process 3
# (pid=30409) process 0 pid 81  len parquets (epochs): 51
# (pid=30409) exit merge process 0
# = = = = = TOTAL DATA ROUTING AND PERISITING TIME: 7535.044472932816 = = = = =
# finish kdtree data routing..

# %%
num_process = 4
problem_type = 2

nora_hdfs = hdfs_base_path + 'NORA/prob' + str(problem_type) + '/'
qdtree_hdfs = hdfs_base_path + 'QdTree/prob' + str(problem_type) + '/'
kdtree_hdfs = hdfs_base_path + 'KDTree/prob' + str(problem_type) + '/'

# base path of Partition
partition_base_path = '/home/centos/PartitionLayout/'

nora_partition = partition_base_path + 'prob' + str(problem_type) + '_nora'
qdtree_partition = partition_base_path + 'prob' + str(problem_type) + '_qdtree'
kdtree_partition = partition_base_path + 'prob' + str(problem_type) + '_kdtree'

if __name__ == '__main__':
    #batch_data_parallel(table_path, nora_partition, chunk_size, used_dims, nora_hdfs, num_dims, num_process, hdfs_private_ip)
    #print('finish nora data routing..')
    #batch_data_parallel(table_path, qdtree_partition, chunk_size, used_dims, qdtree_hdfs, num_dims, num_process, hdfs_private_ip)
    #print('finish qdtree data routing..')
    batch_data_parallel(table_path, kdtree_partition, chunk_size, used_dims, kdtree_hdfs, num_dims, num_process, hdfs_private_ip)
    print('finish kdtree data routing..')
# Out:
# 2021-07-02 10:17:41,035	INFO services.py:1164 -- View the Ray dashboard at http://127.0.0.1:8265
# reading chunk:  0
# (pid=23884) enter data routing process 0 ..
# (pid=23884) proces 0 has routed 0 rows
# reading chunk:  1
# (pid=23883) enter data routing process 1 ..
# (pid=23884) proces 0 has routed 100000 rows
# (pid=23883) proces 1 has routed 0 rows
# reading chunk:  2
# (pid=23884) proces 0 has routed 200000 rows
# (pid=23882) enter data routing process 2 ..
# (pid=23883) proces 1 has routed 100000 rows
# (pid=23882) proces 2 has routed 0 rows
# reading chunk:  3
# (pid=23884) proces 0 has routed 300000 rows
# (pid=23883) proces 1 has routed 200000 rows
# (pid=23881) enter data routing process 3 ..
# (pid=23882) proces 2 has routed 100000 rows
# (pid=23884) proces 0 has routed 400000 rows
# (pid=23881) proces 3 has routed 0 rows
# reading chunk:  4
# (pid=23883) proces 1 has routed 300000 rows
# (pid=23882) proces 2 has routed 200000 rows
# (pid=23881) proces 3 has routed 100000 rows
# (pid=23884) proces 0 has routed 500000 rows
# (pid=23883) proces 1 has routed 400000 rows
# reading chunk:  5
# (pid=23882) proces 2 has routed 300000 rows
# (pid=23881) proces 3 has routed 200000 rows
# (pid=23884) proces 0 has routed 600000 rows
# (pid=23883) proces 1 has routed 500000 rows
# reading chunk:  6
# (pid=23882) proces 2 has routed 400000 rows
# (pid=23881) proces 3 has routed 300000 rows
# (pid=23884) proces 0 has routed 700000 rows
# (pid=23883) proces 1 has routed 600000 rows
# (pid=23882) proces 2 has routed 500000 rows
# (pid=23881) proces 3 has routed 400000 rows
# (pid=23884) proces 0 has routed 800000 rowsreading chunk:
#  7
# (pid=23883) proces 1 has routed 700000 rows
# = = = Process Dump For Chunk 0 to 3 = = =
# (pid=23882) proces 2 has routed 600000 rows
# (pid=23881) proces 3 has routed 500000 rows
# (pid=23884) proces 0 has routed 900000 rows
# (pid=23883) proces 1 has routed 800000 rows
# (pid=23882) proces 2 has routed 700000 rows
# (pid=23881) proces 3 has routed 600000 rows
# (pid=23884) proces 0 has routed 1000000 rows
# (pid=23883) proces 1 has routed 900000 rows
# (pid=23881) proces 3 has routed 700000 rows
# (pid=23882) proces 2 has routed 800000 rows
# (pid=23884) proces 0 has routed 1100000 rows
# (pid=23883) proces 1 has routed 1000000 rows
# (pid=23882) proces 2 has routed 900000 rows
# (pid=23881) proces 3 has routed 800000 rows
# (pid=23884) proces 0 has routed 1200000 rows
# (pid=23883) proces 1 has routed 1100000 rows
# (pid=23881) proces 3 has routed 900000 rows
# (pid=23882) proces 2 has routed 1000000 rows
# (pid=23884) proces 0 has routed 1300000 rows
# (pid=23883) proces 1 has routed 1200000 rows
# (pid=23881) proces 3 has routed 1000000 rows
# (pid=23882) proces 2 has routed 1100000 rows
# (pid=23884) proces 0 has routed 1400000 rows
# (pid=23883) proces 1 has routed 1300000 rows
# (pid=23881) proces 3 has routed 1100000 rows
# (pid=23884) proces 0 has routed 1500000 rows
# (pid=23882) proces 2 has routed 1200000 rows
# (pid=23883) proces 1 has routed 1400000 rows
# (pid=23881) proces 3 has routed 1200000 rows
# (pid=23883) proces 1 has routed 1500000 rows
# (pid=23882) proces 2 has routed 1300000 rows
# (pid=23884) proces 0 has routed 1600000 rows
# (pid=23881) proces 3 has routed 1300000 rows
# (pid=23884) proces 0 has routed 1700000 rows
# (pid=23882) proces 2 has routed 1400000 rows
# (pid=23883) proces 1 has routed 1600000 rows
# (pid=23881) proces 3 has routed 1400000 rows
# (pid=23884) proces 0 has routed 1800000 rows
# (pid=23882) proces 2 has routed 1500000 rows
# (pid=23883) proces 1 has routed 1700000 rows
# (pid=23881) proces 3 has routed 1500000 rows
# (pid=23884) proces 0 has routed 1900000 rows
# (pid=23883) proces 1 has routed 1800000 rows
# (pid=23882) proces 2 has routed 1600000 rows
# (pid=23881) proces 3 has routed 1600000 rows
# (pid=23883) proces 1 has routed 1900000 rows
# (pid=23882) proces 2 has routed 1700000 rows
# (pid=23881) proces 3 has routed 1700000 rows
# (pid=23882) proces 2 has routed 1800000 rows
# (pid=23884) exit data routing process 0 .
# (pid=23881) proces 3 has routed 1800000 rows
# (pid=23884) enter data routing process 4 ..
# (pid=23882) proces 2 has routed 1900000 rows
# (pid=23884) proces 4 has routed 0 rows
# (pid=23883) exit data routing process 1 .
# (pid=23881) proces 3 has routed 1900000 rows
# (pid=23883) enter data routing process 5 ..
# (pid=23884) proces 4 has routed 100000 rows
# (pid=23883) proces 5 has routed 0 rows
# (pid=23884) proces 4 has routed 200000 rows
# (pid=23883) proces 5 has routed 100000 rows
# (pid=23882) exit data routing process 2 .
# (pid=23881) exit data routing process 3 .
# (pid=23882) enter data routing process 6 ..
# (pid=23884) proces 4 has routed 300000 rows
# (pid=23883) proces 5 has routed 200000 rows
# (pid=23881) enter data routing process 7 ..
# (pid=23882) proces 6 has routed 0 rows
# (pid=23881) proces 7 has routed 0 rows
# (pid=23884) proces 4 has routed 400000 rows
# (pid=23883) proces 5 has routed 300000 rows
# (pid=23882) proces 6 has routed 100000 rows
# (pid=23881) proces 7 has routed 100000 rows
# (pid=23884) proces 4 has routed 500000 rows
# (pid=23883) proces 5 has routed 400000 rows
# (pid=23882) proces 6 has routed 200000 rows
# (pid=23881) proces 7 has routed 200000 rows
# (pid=23884) proces 4 has routed 600000 rows
# (pid=23883) proces 5 has routed 500000 rows
# (pid=23882) proces 6 has routed 300000 rows
# (pid=23881) proces 7 has routed 300000 rows
# (pid=23884) proces 4 has routed 700000 rows
# (pid=23883) proces 5 has routed 600000 rows
# (pid=23882) proces 6 has routed 400000 rows
# (pid=23881) proces 7 has routed 400000 rows
# (pid=23884) proces 4 has routed 800000 rows
# (pid=23883) proces 5 has routed 700000 rows
# (pid=23882) proces 6 has routed 500000 rows
# (pid=23881) proces 7 has routed 500000 rows
# (pid=23884) proces 4 has routed 900000 rows
# (pid=23883) proces 5 has routed 800000 rows
# (pid=23882) proces 6 has routed 600000 rows
# (pid=23881) proces 7 has routed 600000 rows
# (pid=23884) proces 4 has routed 1000000 rows
# (pid=23883) proces 5 has routed 900000 rows
# (pid=23882) proces 6 has routed 700000 rows
# (pid=23881) proces 7 has routed 700000 rows
# (pid=23884) proces 4 has routed 1100000 rows
# (pid=23883) proces 5 has routed 1000000 rows
# (pid=23882) proces 6 has routed 800000 rows
# (pid=23881) proces 7 has routed 800000 rows
# (pid=23884) proces 4 has routed 1200000 rows
# (pid=23883) proces 5 has routed 1100000 rows
# (pid=23882) proces 6 has routed 900000 rows
# (pid=23881) proces 7 has routed 900000 rows
# (pid=23884) proces 4 has routed 1300000 rows
# (pid=23883) proces 5 has routed 1200000 rows
# = = = Finish Dump For Chunk(pid=23882) proces 6 has routed 1000000 rows
# (pid=23881) proces 7 has routed 1000000 rows
# (pid=23884) proces 4 has routed 1400000 rows
# (pid=23883) proces 5 has routed 1300000 rows
#  0 to 3 = = =
# = = = TOTAL PROCESSED SO FAR: 8000000 ROWS. TIME SPENT: 170.39120602607727 SECONDS = = =
# (pid=23882) proces 6 has routed 1100000 rows
# (pid=23881) proces 7 has routed 1100000 rows
# (pid=23884) proces 4 has routed 1500000 rows
# (pid=23883) proces 5 has routed 1400000 rows
# reading chunk:  8
# (pid=23882) proces 6 has routed 1200000 rows
# (pid=23881) proces 7 has routed 1200000 rows
# (pid=23884) proces 4 has routed 1600000 rows
# (pid=23883) proces 5 has routed 1500000 rows
# reading chunk:  9
# (pid=23882) proces 6 has routed 1300000 rows
# (pid=23881) proces 7 has routed 1300000 rows
# (pid=23884) proces 4 has routed 1700000 rows
# (pid=23883) proces 5 has routed 1600000 rows
# (pid=23882) proces 6 has routed 1400000 rows
# (pid=23881) proces 7 has routed 1400000 rows
# reading chunk:  10
# (pid=23884) proces 4 has routed 1800000 rows
# (pid=23883) proces 5 has routed 1700000 rows
# (pid=23882) proces 6 has routed 1500000 rows
# (pid=23881) proces 7 has routed 1500000 rows
# (pid=23884) proces 4 has routed 1900000 rows
# (pid=23883) proces 5 has routed 1800000 rows
# reading chunk:  11
# = = = Process Dump For Chunk 4 to 7 = = =
# (pid=23882) proces 6 has routed 1600000 rows
# (pid=23881) proces 7 has routed 1600000 rows
# (pid=23883) proces 5 has routed 1900000 rows
# (pid=23882) proces 6 has routed 1700000 rows
# (pid=23881) proces 7 has routed 1700000 rows
# (pid=23884) exit data routing process 4 .
# (pid=23882) proces 6 has routed 1800000 rows
# (pid=23881) proces 7 has routed 1800000 rows
# (pid=23884) enter data routing process 8 ..
# (pid=23884) proces 8 has routed 0 rows
# (pid=23883) exit data routing process 5 .
# (pid=23882) proces 6 has routed 1900000 rows
# (pid=23881) proces 7 has routed 1900000 rows
# (pid=23884) proces 8 has routed 100000 rows
# (pid=23883) enter data routing process 9 ..
# (pid=23883) proces 9 has routed 0 rows
# (pid=23884) proces 8 has routed 200000 rows
# (pid=23883) proces 9 has routed 100000 rows
# (pid=23884) proces 8 has routed 300000 rows
# (pid=23881) exit data routing process 7 .
# (pid=23882) exit data routing process 6 .
# (pid=23883) proces 9 has routed 200000 rows
# (pid=23881) enter data routing process 10 ..
# (pid=23882) enter data routing process 11 ..
# (pid=23884) proces 8 has routed 400000 rows
# (pid=23881) proces 10 has routed 0 rows
# (pid=23883) proces 9 has routed 300000 rows
# (pid=23882) proces 11 has routed 0 rows
# (pid=23884) proces 8 has routed 500000 rows
# (pid=23881) proces 10 has routed 100000 rows
# (pid=23883) proces 9 has routed 400000 rows
# (pid=23882) proces 11 has routed 100000 rows
# (pid=23884) proces 8 has routed 600000 rows
# (pid=23881) proces 10 has routed 200000 rows
# (pid=23882) proces 11 has routed 200000 rows
# (pid=23883) proces 9 has routed 500000 rows
# (pid=23884) proces 8 has routed 700000 rows
# (pid=23881) proces 10 has routed 300000 rows
# (pid=23882) proces 11 has routed 300000 rows
# (pid=23883) proces 9 has routed 600000 rows
# (pid=23881) proces 10 has routed 400000 rows
# (pid=23884) proces 8 has routed 800000 rows
# (pid=23882) proces 11 has routed 400000 rows
# (pid=23883) proces 9 has routed 700000 rows
# (pid=23884) proces 8 has routed 900000 rows
# (pid=23881) proces 10 has routed 500000 rows
# (pid=23882) proces 11 has routed 500000 rows
# (pid=23883) proces 9 has routed 800000 rows
# (pid=23884) proces 8 has routed 1000000 rows
# (pid=23881) proces 10 has routed 600000 rows
# (pid=23883) proces 9 has routed 900000 rows
# (pid=23882) proces 11 has routed 600000 rows
# (pid=23884) proces 8 has routed 1100000 rows
# (pid=23881) proces 10 has routed 700000 rows
# (pid=23882) proces 11 has routed 700000 rows
# (pid=23883) proces 9 has routed 1000000 rows
# (pid=23884) proces 8 has routed 1200000 rows
# (pid=23881) proces 10 has routed 800000 rows
# (pid=23883) proces 9 has routed 1100000 rows
# (pid=23882) proces 11 has routed 800000 rows
# (pid=23884) proces 8 has routed 1300000 rows
# (pid=23881) proces 10 has routed 900000 rows
# (pid=23883) proces 9 has routed 1200000 rows
# (pid=23882) proces 11 has routed 900000 rows
# (pid=23884) proces 8 has routed 1400000 rows
# (pid=23881) proces 10 has routed 1000000 rows
# (pid=23883) proces 9 has routed 1300000 rows
# (pid=23882) proces 11 has routed 1000000 rows
# (pid=23884) proces 8 has routed 1500000 rows
# (pid=23881) proces 10 has routed 1100000 rows
# (pid=23883) proces 9 has routed 1400000 rows
# = = = Finish Dump For Chunk (pid=23882) proces 11 has routed 1100000 rows4 to 7 = = =
# = = = TOTAL PROCESSED SO FAR: 16000000 ROWS. TIME SPENT:
# 274.6481795310974 SECONDS = = =
# (pid=23881) proces 10 has routed 1200000 rows
# (pid=23884) proces 8 has routed 1600000 rows
# (pid=23883) proces 9 has routed 1500000 rows
# (pid=23882) proces 11 has routed 1200000 rows
# reading chunk:  12
# (pid=23884) proces 8 has routed 1700000 rows
# (pid=23881) proces 10 has routed 1300000 rows
# (pid=23883) proces 9 has routed 1600000 rows
# (pid=23882) proces 11 has routed 1300000 rows
# (pid=23884) proces 8 has routed 1800000 rows
# (pid=23881) proces 10 has routed 1400000 rows
# reading chunk: (pid=23883) proces 9 has routed 1700000 rows
#  13
# (pid=23882) proces 11 has routed 1400000 rows
# (pid=23884) proces 8 has routed 1900000 rows
# (pid=23881) proces 10 has routed 1500000 rows
# (pid=23883) proces 9 has routed 1800000 rows
# (pid=23882) proces 11 has routed 1500000 rows
# reading chunk:  14
# (pid=23883) proces 9 has routed 1900000 rows
# (pid=23881) proces 10 has routed 1600000 rows
# (pid=23882) proces 11 has routed 1600000 rows
# reading chunk:  15
# (pid=23881) proces 10 has routed 1700000 rows
# (pid=23884) exit data routing process 8 .
# = = = Process Dump For Chunk 8 to 11 = = =
# (pid=23882) proces 11 has routed 1700000 rows
# (pid=23884) enter data routing process 12 ..
# (pid=23881) proces 10 has routed 1800000 rows
# (pid=23884) proces 12 has routed 0 rows
# (pid=23883) exit data routing process 9 .
# (pid=23882) proces 11 has routed 1800000 rows
# (pid=23883) enter data routing process 13 ..
# (pid=23881) proces 10 has routed 1900000 rows
# (pid=23884) proces 12 has routed 100000 rows
# (pid=23883) proces 13 has routed 0 rows
# (pid=23882) proces 11 has routed 1900000 rows
# (pid=23884) proces 12 has routed 200000 rows
# (pid=23883) proces 13 has routed 100000 rows
# (pid=23884) proces 12 has routed 300000 rows
# (pid=23883) proces 13 has routed 200000 rows
# (pid=23881) exit data routing process 10 .
# (pid=23882) exit data routing process 11 .
# (pid=23881) enter data routing process 14 ..
# (pid=23884) proces 12 has routed 400000 rows
# (pid=23883) proces 13 has routed 300000 rows
# (pid=23882) enter data routing process 15 ..
# (pid=23881) proces 14 has routed 0 rows
# (pid=23882) proces 15 has routed 0 rows
# (pid=23884) proces 12 has routed 500000 rows
# (pid=23883) proces 13 has routed 400000 rows
# (pid=23881) proces 14 has routed 100000 rows
# (pid=23882) proces 15 has routed 100000 rows
# (pid=23884) proces 12 has routed 600000 rows
# (pid=23883) proces 13 has routed 500000 rows
# (pid=23881) proces 14 has routed 200000 rows
# (pid=23882) proces 15 has routed 200000 rows
# (pid=23884) proces 12 has routed 700000 rows
# (pid=23883) proces 13 has routed 600000 rows
# (pid=23881) proces 14 has routed 300000 rows
# (pid=23882) proces 15 has routed 300000 rows
# (pid=23884) proces 12 has routed 800000 rows
# (pid=23883) proces 13 has routed 700000 rows
# (pid=23881) proces 14 has routed 400000 rows
# (pid=23882) proces 15 has routed 400000 rows
# (pid=23884) proces 12 has routed 900000 rows
# (pid=23883) proces 13 has routed 800000 rows
# (pid=23881) proces 14 has routed 500000 rows
# (pid=23882) proces 15 has routed 500000 rows
# (pid=23884) proces 12 has routed 1000000 rows
# (pid=23883) proces 13 has routed 900000 rows
# (pid=23881) proces 14 has routed 600000 rows
# (pid=23882) proces 15 has routed 600000 rows
# (pid=23884) proces 12 has routed 1100000 rows
# (pid=23883) proces 13 has routed 1000000 rows
# (pid=23881) proces 14 has routed 700000 rows
# (pid=23882) proces 15 has routed 700000 rows
# (pid=23884) proces 12 has routed 1200000 rows
# (pid=23883) proces 13 has routed 1100000 rows
# (pid=23881) proces 14 has routed 800000 rows
# (pid=23882) proces 15 has routed 800000 rows
# (pid=23884) proces 12 has routed 1300000 rows
# (pid=23883) proces 13 has routed 1200000 rows
# (pid=23881) proces 14 has routed 900000 rows
# (pid=23882) proces 15 has routed 900000 rows
# (pid=23884) proces 12 has routed 1400000 rows
# (pid=23883) proces 13 has routed 1300000 rows
# (pid=23881) proces 14 has routed 1000000 rows
# (pid=23882) proces 15 has routed 1000000 rows
# (pid=23883) proces 13 has routed 1400000 rows
# (pid=23884) proces 12 has routed 1500000 rows
# (pid=23881) proces 14 has routed 1100000 rows
# (pid=23882) proces 15 has routed 1100000 rows
# (pid=23884) proces 12 has routed 1600000 rows
# (pid=23883) proces 13 has routed 1500000 rows
# (pid=23881) proces 14 has routed 1200000 rows
# = = = Finish Dump For Chunk (pid=23884) proces 12 has routed 1700000 rows
# (pid=23882) proces 15 has routed 1200000 rows
# 8 to 11 = = =
# = = = TOTAL PROCESSED SO FAR: 24000000 ROWS. TIME SPENT: 376.78824853897095 SECONDS = = =
# (pid=23883) proces 13 has routed 1600000 rows
# (pid=23881) proces 14 has routed 1300000 rows
# (pid=23884) proces 12 has routed 1800000 rows
# (pid=23882) proces 15 has routed 1300000 rows
# reading chunk:  16
# (pid=23883) proces 13 has routed 1700000 rows
# (pid=23881) proces 14 has routed 1400000 rows
# (pid=23883) proces 13 has routed 1800000 rows
# (pid=23882) proces 15 has routed 1400000 rows
# (pid=23884) proces 12 has routed 1900000 rows
# reading chunk:  17
# (pid=23881) proces 14 has routed 1500000 rows
# (pid=23882) proces 15 has routed 1500000 rows
# (pid=23883) proces 13 has routed 1900000 rows
# (pid=23881) proces 14 has routed 1600000 rows
# reading chunk:  18
# (pid=23882) proces 15 has routed 1600000 rows
# (pid=23884) exit data routing process 12 .
# (pid=23881) proces 14 has routed 1700000 rows
# (pid=23884) enter data routing process 16 ..
# (pid=23882) proces 15 has routed 1700000 rowsreading chunk:  19
#
# (pid=23884) proces 16 has routed 0 rows
# (pid=23881) proces 14 has routed 1800000 rows
# (pid=23883) exit data routing process 13 .
# = = = Process Dump For Chunk 12 to 15 = = =
# (pid=23882) proces 15 has routed 1800000 rows
# (pid=23883) enter data routing process 17 ..
# (pid=23884) proces 16 has routed 100000 rows
# (pid=23883) proces 17 has routed 0 rows
# (pid=23881) proces 14 has routed 1900000 rows
# (pid=23882) proces 15 has routed 1900000 rows
# (pid=23884) proces 16 has routed 200000 rows
# (pid=23883) proces 17 has routed 100000 rows
# (pid=23884) proces 16 has routed 300000 rows
# (pid=23883) proces 17 has routed 200000 rows
# (pid=23881) exit data routing process 14 .
# (pid=23884) proces 16 has routed 400000 rows
# (pid=23883) proces 17 has routed 300000 rows
# (pid=23882) exit data routing process 15 .
# (pid=23881) enter data routing process 18 ..
# (pid=23881) proces 18 has routed 0 rows
# (pid=23882) enter data routing process 19 ..
# (pid=23884) proces 16 has routed 500000 rows
# (pid=23883) proces 17 has routed 400000 rows
# (pid=23882) proces 19 has routed 0 rows
# (pid=23881) proces 18 has routed 100000 rows
# (pid=23884) proces 16 has routed 600000 rows
# (pid=23883) proces 17 has routed 500000 rows
# (pid=23882) proces 19 has routed 100000 rows
# (pid=23881) proces 18 has routed 200000 rows
# (pid=23884) proces 16 has routed 700000 rows
# (pid=23883) proces 17 has routed 600000 rows
# (pid=23882) proces 19 has routed 200000 rows
# (pid=23881) proces 18 has routed 300000 rows
# (pid=23883) proces 17 has routed 700000 rows
# (pid=23882) proces 19 has routed 300000 rows
# (pid=23884) proces 16 has routed 800000 rows
# (pid=23881) proces 18 has routed 400000 rows
# (pid=23883) proces 17 has routed 800000 rows
# (pid=23884) proces 16 has routed 900000 rows
# (pid=23882) proces 19 has routed 400000 rows
# (pid=23881) proces 18 has routed 500000 rows
# (pid=23883) proces 17 has routed 900000 rows
# (pid=23882) proces 19 has routed 500000 rows
# (pid=23884) proces 16 has routed 1000000 rows
# (pid=23881) proces 18 has routed 600000 rows
# (pid=23883) proces 17 has routed 1000000 rows
# (pid=23884) proces 16 has routed 1100000 rows
# (pid=23882) proces 19 has routed 600000 rows
# (pid=23881) proces 18 has routed 700000 rows
# (pid=23883) proces 17 has routed 1100000 rows
# (pid=23884) proces 16 has routed 1200000 rows
# (pid=23882) proces 19 has routed 700000 rows
# (pid=23881) proces 18 has routed 800000 rows
# (pid=23883) proces 17 has routed 1200000 rows
# (pid=23884) proces 16 has routed 1300000 rows
# (pid=23882) proces 19 has routed 800000 rows
# (pid=23881) proces 18 has routed 900000 rows
# (pid=23883) proces 17 has routed 1300000 rows
# (pid=23884) proces 16 has routed 1400000 rows
# (pid=23882) proces 19 has routed 900000 rows
# (pid=23881) proces 18 has routed 1000000 rows
# (pid=23883) proces 17 has routed 1400000 rows
# (pid=23884) proces 16 has routed 1500000 rows
# (pid=23882) proces 19 has routed 1000000 rows
# (pid=23881) proces 18 has routed 1100000 rows
# (pid=23883) proces 17 has routed 1500000 rows
# (pid=23882) proces 19 has routed 1100000 rows
# (pid=23884) proces 16 has routed 1600000 rows
# (pid=23881) proces 18 has routed 1200000 rows
# = = = Finish Dump For Chunk 12 to 15 = = =
# = = = TOTAL PROCESSED SO FAR: 32000000 ROWS. TIME SPENT: 473.68314123153687 SECONDS = = =
# (pid=23883) proces 17 has routed 1600000 rows
# (pid=23884) proces 16 has routed 1700000 rows
# (pid=23882) proces 19 has routed 1200000 rows
# (pid=23883) proces 17 has routed 1700000 rowsreading chunk:  20
#
# (pid=23881) proces 18 has routed 1300000 rows
# (pid=23884) proces 16 has routed 1800000 rows
# (pid=23882) proces 19 has routed 1300000 rows
# (pid=23883) proces 17 has routed 1800000 rows
# (pid=23881) proces 18 has routed 1400000 rows
# (pid=23884) proces 16 has routed 1900000 rows
# reading chunk:  21
# (pid=23882) proces 19 has routed 1400000 rows
# (pid=23883) proces 17 has routed 1900000 rows
# (pid=23881) proces 18 has routed 1500000 rows
# (pid=23882) proces 19 has routed 1500000 rows
# reading chunk:  22
# (pid=23881) proces 18 has routed 1600000 rows
# (pid=23884) exit data routing process 16 .
# (pid=23882) proces 19 has routed 1600000 rows
# (pid=23883) exit data routing process 17 .
# (pid=23881) proces 18 has routed 1700000 rows
# (pid=23884) enter data routing process 20 ..
# reading chunk:  23
# (pid=23884) proces 20 has routed 0 rows
# (pid=23882) proces 19 has routed 1700000 rows
# (pid=23883) enter data routing process 21 ..
# = = = Process Dump For Chunk 16 to 19 = = =
# (pid=23883) proces 21 has routed 0 rows
# (pid=23881) proces 18 has routed 1800000 rows
# (pid=23884) proces 20 has routed 100000 rows
# (pid=23882) proces 19 has routed 1800000 rows
# (pid=23883) proces 21 has routed 100000 rows
# (pid=23881) proces 18 has routed 1900000 rows
# (pid=23882) proces 19 has routed 1900000 rows
# (pid=23884) proces 20 has routed 200000 rows
# (pid=23883) proces 21 has routed 200000 rows
# (pid=23884) proces 20 has routed 300000 rows
# (pid=23883) proces 21 has routed 300000 rows
# (pid=23881) exit data routing process 18 .
# (pid=23884) proces 20 has routed 400000 rows
# (pid=23881) enter data routing process 22 ..
# (pid=23882) exit data routing process 19 .
# (pid=23883) proces 21 has routed 400000 rows
# (pid=23881) proces 22 has routed 0 rows
# (pid=23884) proces 20 has routed 500000 rows
# (pid=23882) enter data routing process 23 ..
# (pid=23883) proces 21 has routed 500000 rows
# (pid=23882) proces 23 has routed 0 rows
# (pid=23881) proces 22 has routed 100000 rows
# (pid=23884) proces 20 has routed 600000 rows
# (pid=23883) proces 21 has routed 600000 rows
# (pid=23882) proces 23 has routed 100000 rows
# (pid=23881) proces 22 has routed 200000 rows
# (pid=23884) proces 20 has routed 700000 rows
# (pid=23883) proces 21 has routed 700000 rows
# (pid=23882) proces 23 has routed 200000 rows
# (pid=23881) proces 22 has routed 300000 rows
# (pid=23884) proces 20 has routed 800000 rows
# (pid=23883) proces 21 has routed 800000 rows
# (pid=23882) proces 23 has routed 300000 rows
# (pid=23881) proces 22 has routed 400000 rows
# (pid=23884) proces 20 has routed 900000 rows
# (pid=23883) proces 21 has routed 900000 rows
# (pid=23882) proces 23 has routed 400000 rows
# (pid=23881) proces 22 has routed 500000 rows
# (pid=23884) proces 20 has routed 1000000 rows
# (pid=23883) proces 21 has routed 1000000 rows
# (pid=23882) proces 23 has routed 500000 rows
# (pid=23881) proces 22 has routed 600000 rows
# (pid=23884) proces 20 has routed 1100000 rows
# (pid=23883) proces 21 has routed 1100000 rows
# (pid=23882) proces 23 has routed 600000 rows
# (pid=23881) proces 22 has routed 700000 rows
# (pid=23884) proces 20 has routed 1200000 rows
# (pid=23883) proces 21 has routed 1200000 rows
# (pid=23882) proces 23 has routed 700000 rows
# (pid=23881) proces 22 has routed 800000 rows
# (pid=23884) proces 20 has routed 1300000 rows
# (pid=23883) proces 21 has routed 1300000 rows
# (pid=23882) proces 23 has routed 800000 rows
# (pid=23881) proces 22 has routed 900000 rows
# (pid=23884) proces 20 has routed 1400000 rows
# (pid=23883) proces 21 has routed 1400000 rows
# (pid=23881) proces 22 has routed 1000000 rows
# (pid=23882) proces 23 has routed 900000 rows
# (pid=23884) proces 20 has routed 1500000 rows
# (pid=23883) proces 21 has routed 1500000 rows
# (pid=23881) proces 22 has routed 1100000 rows
# (pid=23882) proces 23 has routed 1000000 rows
# (pid=23884) proces 20 has routed 1600000 rows
# (pid=23883) proces 21 has routed 1600000 rows
# (pid=23882) proces 23 has routed 1100000 rows
# (pid=23881) proces 22 has routed 1200000 rows
# (pid=23884) proces 20 has routed 1700000 rows
# (pid=23883) proces 21 has routed 1700000 rows
# (pid=23881) proces 22 has routed 1300000 rows
# (pid=23882) proces 23 has routed 1200000 rows
# = = = Finish Dump For Chunk(pid=23884) proces 20 has routed 1800000 rows 16 to 19
# (pid=23883) proces 21 has routed 1800000 rows
# (pid=23881) proces 22 has routed 1400000 rows
# (pid=23882) proces 23 has routed 1300000 rows
# = = =
# = = = TOTAL PROCESSED SO FAR: 40000000 ROWS. TIME SPENT: 579.9187850952148 SECONDS = = =
# (pid=23884) proces 20 has routed 1900000 rows
# (pid=23883) proces 21 has routed 1900000 rows
# reading chunk:  24
# (pid=23882) proces 23 has routed 1400000 rows
# (pid=23881) proces 22 has routed 1500000 rows
# (pid=23881) proces 22 has routed 1600000 rows
# (pid=23882) proces 23 has routed 1500000 rows
# reading chunk:  25
# (pid=23884) exit data routing process 20 .
# (pid=23881) proces 22 has routed 1700000 rows
# (pid=23883) exit data routing process 21 .
# (pid=23882) proces 23 has routed 1600000 rows
# (pid=23884) enter data routing process 24 ..
# (pid=23883) enter data routing process 25 ..
# reading chunk:  26
# (pid=23884) proces 24 has routed 0 rows
# (pid=23881) proces 22 has routed 1800000 rows
# (pid=23882) proces 23 has routed 1700000 rows
# (pid=23883) proces 25 has routed 0 rows
# (pid=23884) proces 24 has routed 100000 rows
# (pid=23883) proces 25 has routed 100000 rows
# (pid=23882) proces 23 has routed 1800000 rows
# (pid=23881) proces 22 has routed 1900000 rows
# reading chunk:  27
# = = = Process Dump For Chunk 20 to 23 = = =
# (pid=23884) proces 24 has routed 200000 rows
# (pid=23883) proces 25 has routed 200000 rows
# (pid=23882) proces 23 has routed 1900000 rows
# (pid=23884) proces 24 has routed 300000 rows
# (pid=23883) proces 25 has routed 300000 rows
# (pid=23881) exit data routing process 22 .
# (pid=23884) proces 24 has routed 400000 rows
# (pid=23881) enter data routing process 26 ..
# (pid=23883) proces 25 has routed 400000 rows
# (pid=23881) proces 26 has routed 0 rows
# (pid=23882) exit data routing process 23 .
# (pid=23884) proces 24 has routed 500000 rows
# (pid=23883) proces 25 has routed 500000 rows
# (pid=23882) enter data routing process 27 ..
# (pid=23881) proces 26 has routed 100000 rows
# (pid=23882) proces 27 has routed 0 rows
# (pid=23884) proces 24 has routed 600000 rows
# (pid=23883) proces 25 has routed 600000 rows
# (pid=23881) proces 26 has routed 200000 rows
# (pid=23882) proces 27 has routed 100000 rows
# (pid=23884) proces 24 has routed 700000 rows
# (pid=23883) proces 25 has routed 700000 rows
# (pid=23881) proces 26 has routed 300000 rows
# (pid=23882) proces 27 has routed 200000 rows
# (pid=23884) proces 24 has routed 800000 rows
# (pid=23883) proces 25 has routed 800000 rows
# (pid=23881) proces 26 has routed 400000 rows
# (pid=23882) proces 27 has routed 300000 rows
# (pid=23884) proces 24 has routed 900000 rows
# (pid=23883) proces 25 has routed 900000 rows
# (pid=23881) proces 26 has routed 500000 rows
# (pid=23882) proces 27 has routed 400000 rows
# (pid=23884) proces 24 has routed 1000000 rows
# (pid=23883) proces 25 has routed 1000000 rows
# (pid=23881) proces 26 has routed 600000 rows
# (pid=23882) proces 27 has routed 500000 rows
# (pid=23884) proces 24 has routed 1100000 rows
# (pid=23883) proces 25 has routed 1100000 rows
# (pid=23881) proces 26 has routed 700000 rows
# (pid=23882) proces 27 has routed 600000 rows
# (pid=23884) proces 24 has routed 1200000 rows
# (pid=23883) proces 25 has routed 1200000 rows
# (pid=23881) proces 26 has routed 800000 rows
# (pid=23882) proces 27 has routed 700000 rows
# (pid=23884) proces 24 has routed 1300000 rows
# (pid=23883) proces 25 has routed 1300000 rows
# (pid=23881) proces 26 has routed 900000 rows
# (pid=23882) proces 27 has routed 800000 rows
# (pid=23884) proces 24 has routed 1400000 rows
# (pid=23883) proces 25 has routed 1400000 rows
# (pid=23882) proces 27 has routed 900000 rows
# (pid=23881) proces 26 has routed 1000000 rows
# (pid=23884) proces 24 has routed 1500000 rows
# (pid=23883) proces 25 has routed 1500000 rows
# (pid=23881) proces 26 has routed 1100000 rows
# (pid=23882) proces 27 has routed 1000000 rows
# (pid=23884) proces 24 has routed 1600000 rows
# (pid=23883) proces 25 has routed 1600000 rows
# = = = Finish Dump For Chunk(pid=23881) proces 26 has routed 1200000 rows
#  20 (pid=23882) proces 27 has routed 1100000 rowsto 23 = = =
#
# = = = TOTAL PROCESSED SO FAR: 48000000 ROWS. TIME SPENT: 671.1228861808777 SECONDS = = =
# (pid=23884) proces 24 has routed 1700000 rows
# (pid=23883) proces 25 has routed 1700000 rows
# (pid=23882) proces 27 has routed 1200000 rows
# (pid=23881) proces 26 has routed 1300000 rows
# reading chunk:  28
# (pid=23884) proces 24 has routed 1800000 rows
# (pid=23883) proces 25 has routed 1800000 rows
# (pid=23881) proces 26 has routed 1400000 rows
# (pid=23882) proces 27 has routed 1300000 rows
# (pid=23884) proces 24 has routed 1900000 rows
# (pid=23883) proces 25 has routed 1900000 rows
# reading chunk:  29
# (pid=23881) proces 26 has routed 1500000 rows
# (pid=23882) proces 27 has routed 1400000 rows
# (pid=23882) proces 27 has routed 1500000 rows
# reading chunk:  30
# (pid=23881) proces 26 has routed 1600000 rows
# (pid=23883) exit data routing process 25 .
# (pid=23884) exit data routing process 24 .
# (pid=23882) proces 27 has routed 1600000 rows
# (pid=23881) proces 26 has routed 1700000 rows
# (pid=23883) enter data routing process 28 ..
# (pid=23884) enter data routing process 29 ..
# reading chunk:  31
# (pid=23883) proces 28 has routed 0 rows
# (pid=23884) proces 29 has routed 0 rows
# = = = Process Dump For Chunk 24 to 27 = = =
# (pid=23881) proces 26 has routed 1800000 rows
# (pid=23882) proces 27 has routed 1700000 rows
# (pid=23883) proces 28 has routed 100000 rows
# (pid=23884) proces 29 has routed 100000 rows
# (pid=23881) proces 26 has routed 1900000 rows
# (pid=23882) proces 27 has routed 1800000 rows
# (pid=23883) proces 28 has routed 200000 rows
# (pid=23884) proces 29 has routed 200000 rows
# (pid=23882) proces 27 has routed 1900000 rows
# (pid=23883) proces 28 has routed 300000 rows
# (pid=23884) proces 29 has routed 300000 rows
# (pid=23881) exit data routing process 26 .
# (pid=23883) proces 28 has routed 400000 rows
# (pid=23884) proces 29 has routed 400000 rows
# (pid=23881) enter data routing process 30 ..
# (pid=23881) proces 30 has routed 0 rows
# (pid=23882) exit data routing process 27 .
# (pid=23883) proces 28 has routed 500000 rows
# (pid=23884) proces 29 has routed 500000 rows
# (pid=23882) enter data routing process 31 ..
# (pid=23881) proces 30 has routed 100000 rows
# (pid=23882) proces 31 has routed 0 rows
# (pid=23883) proces 28 has routed 600000 rows
# (pid=23884) proces 29 has routed 600000 rows
# (pid=23881) proces 30 has routed 200000 rows
# (pid=23882) proces 31 has routed 100000 rows
# (pid=23883) proces 28 has routed 700000 rows
# (pid=23884) proces 29 has routed 700000 rows
# (pid=23881) proces 30 has routed 300000 rows
# (pid=23882) proces 31 has routed 200000 rows
# (pid=23883) proces 28 has routed 800000 rows
# (pid=23884) proces 29 has routed 800000 rows
# (pid=23881) proces 30 has routed 400000 rows
# (pid=23882) proces 31 has routed 300000 rows
# (pid=23884) proces 29 has routed 900000 rows
# (pid=23883) proces 28 has routed 900000 rows
# (pid=23881) proces 30 has routed 500000 rows
# (pid=23882) proces 31 has routed 400000 rows
# (pid=23883) proces 28 has routed 1000000 rows
# (pid=23884) proces 29 has routed 1000000 rows
# (pid=23881) proces 30 has routed 600000 rows
# (pid=23882) proces 31 has routed 500000 rows
# (pid=23883) proces 28 has routed 1100000 rows
# (pid=23884) proces 29 has routed 1100000 rows
# (pid=23881) proces 30 has routed 700000 rows
# (pid=23882) proces 31 has routed 600000 rows
# (pid=23884) proces 29 has routed 1200000 rows
# (pid=23883) proces 28 has routed 1200000 rows
# (pid=23881) proces 30 has routed 800000 rows
# (pid=23882) proces 31 has routed 700000 rows
# (pid=23884) proces 29 has routed 1300000 rows
# (pid=23883) proces 28 has routed 1300000 rows
# (pid=23881) proces 30 has routed 900000 rows
# (pid=23882) proces 31 has routed 800000 rows
# (pid=23884) proces 29 has routed 1400000 rows
# (pid=23883) proces 28 has routed 1400000 rows
# (pid=23881) proces 30 has routed 1000000 rows
# (pid=23882) proces 31 has routed 900000 rows
# (pid=23884) proces 29 has routed 1500000 rows
# (pid=23883) proces 28 has routed 1500000 rows
# (pid=23881) proces 30 has routed 1100000 rows= = = Finish Dump For Chunk
# (pid=23882) proces 31 has routed 1000000 rows
# (pid=23884) proces 29 has routed 1600000 rows
#  24 to 27 = = =
# = = = TOTAL PROCESSED SO FAR: 56000000 ROWS. TIME SPENT: 764.5928883552551 SECONDS = = =
# (pid=23883) proces 28 has routed 1600000 rows
# (pid=23881) proces 30 has routed 1200000 rows
# (pid=23884) proces 29 has routed 1700000 rows
# (pid=23883) proces 28 has routed 1700000 rows
# (pid=23882) proces 31 has routed 1100000 rows
# reading chunk:  32
# (pid=23881) proces 30 has routed 1300000 rows
# (pid=23884) proces 29 has routed 1800000 rows
# (pid=23883) proces 28 has routed 1800000 rows
# (pid=23882) proces 31 has routed 1200000 rows
# reading chunk:  33
# (pid=23881) proces 30 has routed 1400000 rows
# (pid=23882) proces 31 has routed 1300000 rows
# (pid=23884) proces 29 has routed 1900000 rows
# (pid=23883) proces 28 has routed 1900000 rows
# (pid=23881) proces 30 has routed 1500000 rows
# reading chunk:  34
# (pid=23882) proces 31 has routed 1400000 rows
# (pid=23881) proces 30 has routed 1600000 rows
# (pid=23882) proces 31 has routed 1500000 rowsreading chunk:
#  35
# (pid=23884) exit data routing process 29 .
# (pid=23883) exit data routing process 28 .
# (pid=23881) proces 30 has routed 1700000 rows
# = = = Process Dump For Chunk 28 to 31 = = =
# (pid=23884) enter data routing process 32 ..
# (pid=23883) enter data routing process 33 ..
# (pid=23882) proces 31 has routed 1600000 rows
# (pid=23884) proces 32 has routed 0 rows
# (pid=23883) proces 33 has routed 0 rows
# (pid=23881) proces 30 has routed 1800000 rows
# (pid=23882) proces 31 has routed 1700000 rows
# (pid=23884) proces 32 has routed 100000 rows
# (pid=23883) proces 33 has routed 100000 rows
# (pid=23881) proces 30 has routed 1900000 rows
# (pid=23882) proces 31 has routed 1800000 rows
# (pid=23884) proces 32 has routed 200000 rows
# (pid=23883) proces 33 has routed 200000 rows
# (pid=23884) proces 32 has routed 300000 rows
# (pid=23883) proces 33 has routed 300000 rows
# (pid=23882) proces 31 has routed 1900000 rows
# (pid=23881) exit data routing process 30 .
# (pid=23884) proces 32 has routed 400000 rows
# (pid=23883) proces 33 has routed 400000 rows
# (pid=23881) enter data routing process 34 ..
# (pid=23881) proces 34 has routed 0 rows
# (pid=23884) proces 32 has routed 500000 rows
# (pid=23883) proces 33 has routed 500000 rows
# (pid=23882) exit data routing process 31 .
# (pid=23881) proces 34 has routed 100000 rows
# (pid=23884) proces 32 has routed 600000 rows
# (pid=23882) enter data routing process 35 ..
# (pid=23882) proces 35 has routed 0 rows
# (pid=23881) proces 34 has routed 200000 rows
# (pid=23883) proces 33 has routed 600000 rows
# (pid=23884) proces 32 has routed 700000 rows
# (pid=23882) proces 35 has routed 100000 rows
# (pid=23881) proces 34 has routed 300000 rows
# (pid=23883) proces 33 has routed 700000 rows
# (pid=23884) proces 32 has routed 800000 rows
# (pid=23882) proces 35 has routed 200000 rows
# (pid=23881) proces 34 has routed 400000 rows
# (pid=23884) proces 32 has routed 900000 rows
# (pid=23883) proces 33 has routed 800000 rows
# (pid=23882) proces 35 has routed 300000 rows
# (pid=23881) proces 34 has routed 500000 rows
# (pid=23884) proces 32 has routed 1000000 rows
# (pid=23883) proces 33 has routed 900000 rows
# (pid=23882) proces 35 has routed 400000 rows
# (pid=23881) proces 34 has routed 600000 rows
# (pid=23884) proces 32 has routed 1100000 rows
# (pid=23882) proces 35 has routed 500000 rows
# (pid=23883) proces 33 has routed 1000000 rows
# (pid=23881) proces 34 has routed 700000 rows
# (pid=23884) proces 32 has routed 1200000 rows
# (pid=23882) proces 35 has routed 600000 rows
# (pid=23881) proces 34 has routed 800000 rows
# (pid=23883) proces 33 has routed 1100000 rows
# (pid=23884) proces 32 has routed 1300000 rows
# (pid=23882) proces 35 has routed 700000 rows
# (pid=23881) proces 34 has routed 900000 rows
# (pid=23883) proces 33 has routed 1200000 rows
# (pid=23884) proces 32 has routed 1400000 rows
# (pid=23882) proces 35 has routed 800000 rows
# (pid=23881) proces 34 has routed 1000000 rows
# (pid=23884) proces 32 has routed 1500000 rows
# (pid=23883) proces 33 has routed 1300000 rows
# (pid=23882) proces 35 has routed 900000 rows
# (pid=23881) proces 34 has routed 1100000 rows
# (pid=23884) proces 32 has routed 1600000 rows
# (pid=23883) proces 33 has routed 1400000 rows
# (pid=23881) proces 34 has routed 1200000 rows
# (pid=23882) proces 35 has routed 1000000 rows
# = = = Finish Dump For Chunk 28 to 31 = = =
# = = = TOTAL PROCESSED SO FAR: 64000000 ROWS. TIME SPENT: (pid=23884) proces 32 has routed 1700000 rows
# 868.4480702877045 SECONDS = = =
# (pid=23883) proces 33 has routed 1500000 rows
# (pid=23882) proces 35 has routed 1100000 rows
# (pid=23881) proces 34 has routed 1300000 rows
# (pid=23884) proces 32 has routed 1800000 rows
# reading chunk:  36
# (pid=23882) proces 35 has routed 1200000 rows
# (pid=23881) proces 34 has routed 1400000 rows
# (pid=23883) proces 33 has routed 1600000 rows
# (pid=23884) proces 32 has routed 1900000 rows
# (pid=23881) proces 34 has routed 1500000 rows
# (pid=23882) proces 35 has routed 1300000 rows
# reading chunk:  37
# (pid=23883) proces 33 has routed 1700000 rows
# (pid=23882) proces 35 has routed 1400000 rows
# (pid=23881) proces 34 has routed 1600000 rows
# (pid=23884) exit data routing process 32 .
# (pid=23883) proces 33 has routed 1800000 rows
# reading chunk:  38
# (pid=23882) proces 35 has routed 1500000 rows
# (pid=23881) proces 34 has routed 1700000 rows
# (pid=23884) enter data routing process 36 ..
# (pid=23884) proces 36 has routed 0 rows
# (pid=23883) proces 33 has routed 1900000 rows
# (pid=23881) proces 34 has routed 1800000 rows
# reading chunk:  39
# (pid=23882) proces 35 has routed 1600000 rows
# (pid=23884) proces 36 has routed 100000 rows
# = = = Process Dump For Chunk 32 to 35 = = =
# (pid=23881) proces 34 has routed 1900000 rows
# (pid=23882) proces 35 has routed 1700000 rows
# (pid=23884) proces 36 has routed 200000 rows
# (pid=23883) exit data routing process 33 .
# (pid=23882) proces 35 has routed 1800000 rows
# (pid=23884) proces 36 has routed 300000 rows
# (pid=23883) enter data routing process 37 ..
# (pid=23881) exit data routing process 34 .
# (pid=23882) proces 35 has routed 1900000 rows
# (pid=23883) proces 37 has routed 0 rows
# (pid=23884) proces 36 has routed 400000 rows
# (pid=23881) enter data routing process 38 ..
# (pid=23883) proces 37 has routed 100000 rows
# (pid=23881) proces 38 has routed 0 rows
# (pid=23884) proces 36 has routed 500000 rows
# (pid=23883) proces 37 has routed 200000 rows
# (pid=23882) exit data routing process 35 .
# (pid=23881) proces 38 has routed 100000 rows
# (pid=23884) proces 36 has routed 600000 rows
# (pid=23882) enter data routing process 39 ..
# (pid=23883) proces 37 has routed 300000 rows
# (pid=23882) proces 39 has routed 0 rows
# (pid=23884) proces 36 has routed 700000 rows
# (pid=23881) proces 38 has routed 200000 rows
# (pid=23883) proces 37 has routed 400000 rows
# (pid=23882) proces 39 has routed 100000 rows
# (pid=23884) proces 36 has routed 800000 rows
# (pid=23881) proces 38 has routed 300000 rows
# (pid=23883) proces 37 has routed 500000 rows
# (pid=23882) proces 39 has routed 200000 rows
# (pid=23884) proces 36 has routed 900000 rows
# (pid=23881) proces 38 has routed 400000 rows
# (pid=23883) proces 37 has routed 600000 rows
# (pid=23882) proces 39 has routed 300000 rows
# (pid=23884) proces 36 has routed 1000000 rows
# (pid=23883) proces 37 has routed 700000 rows
# (pid=23881) proces 38 has routed 500000 rows
# (pid=23882) proces 39 has routed 400000 rows
# (pid=23884) proces 36 has routed 1100000 rows
# (pid=23883) proces 37 has routed 800000 rows
# (pid=23882) proces 39 has routed 500000 rows
# (pid=23881) proces 38 has routed 600000 rows
# (pid=23884) proces 36 has routed 1200000 rows
# (pid=23883) proces 37 has routed 900000 rows
# (pid=23882) proces 39 has routed 600000 rows
# (pid=23884) proces 36 has routed 1300000 rows
# (pid=23881) proces 38 has routed 700000 rows
# (pid=23883) proces 37 has routed 1000000 rows
# (pid=23882) proces 39 has routed 700000 rows
# (pid=23884) proces 36 has routed 1400000 rows
# (pid=23881) proces 38 has routed 800000 rows
# (pid=23883) proces 37 has routed 1100000 rows
# (pid=23882) proces 39 has routed 800000 rows
# (pid=23884) proces 36 has routed 1500000 rows
# (pid=23883) proces 37 has routed 1200000 rows
# (pid=23881) proces 38 has routed 900000 rows
# (pid=23882) proces 39 has routed 900000 rows
# (pid=23884) proces 36 has routed 1600000 rows
# (pid=23883) proces 37 has routed 1300000 rows
# (pid=23881) proces 38 has routed 1000000 rows
# (pid=23882) proces 39 has routed 1000000 rows
# (pid=23884) proces 36 has routed 1700000 rows
# (pid=23883) proces 37 has routed 1400000 rows
# (pid=23882) proces 39 has routed 1100000 rows
# (pid=23881) proces 38 has routed 1100000 rows
# (pid=23884) proces 36 has routed 1800000 rows
# (pid=23883) proces 37 has routed 1500000 rows
# (pid=23882) proces 39 has routed 1200000 rows
# (pid=23881) proces 38 has routed 1200000 rows
# (pid=23884) proces 36 has routed 1900000 rows
# (pid=23883) proces 37 has routed 1600000 rows
# = = = Finish Dump For Chunk(pid=23882) proces 39 has routed 1300000 rows
#  32 to 35 = = =
# = = = TOTAL PROCESSED SO FAR: 72000000 ROWS. TIME SPENT: 978.1106171607971 SECONDS = = =
# (pid=23881) proces 38 has routed 1300000 rows
# (pid=23883) proces 37 has routed 1700000 rows
# (pid=23882) proces 39 has routed 1400000 rows
# reading chunk: (pid=23883) proces 37 has routed 1800000 rows 40
#
# (pid=23884) exit data routing process 36 .
# (pid=23881) proces 38 has routed 1400000 rows
# (pid=23882) proces 39 has routed 1500000 rows
# (pid=23884) enter data routing process 40 ..
# (pid=23884) proces 40 has routed 0 rows
# (pid=23883) proces 37 has routed 1900000 rows
# (pid=23881) proces 38 has routed 1500000 rows
# reading chunk:  41
# (pid=23882) proces 39 has routed 1600000 rows
# (pid=23884) proces 40 has routed 100000 rows
# (pid=23882) proces 39 has routed 1700000 rows
# (pid=23881) proces 38 has routed 1600000 rows
# reading chunk:  42
# (pid=23883) exit data routing process 37 .
# (pid=23884) proces 40 has routed 200000 rows
# (pid=23882) proces 39 has routed 1800000 rows
# (pid=23881) proces 38 has routed 1700000 rows
# (pid=23883) enter data routing process 41 ..
# reading chunk:  43
# (pid=23883) proces 41 has routed 0 rows
# (pid=23884) proces 40 has routed 300000 rows
# (pid=23882) proces 39 has routed 1900000 rows
# = = = Process Dump For Chunk 36 to 39 = = =
# (pid=23881) proces 38 has routed 1800000 rows
# (pid=23883) proces 41 has routed 100000 rows
# (pid=23884) proces 40 has routed 400000 rows
# (pid=23881) proces 38 has routed 1900000 rows
# (pid=23884) proces 40 has routed 500000 rows
# (pid=23883) proces 41 has routed 200000 rows
# (pid=23882) exit data routing process 39 .
# (pid=23882) enter data routing process 42 ..
# (pid=23884) proces 40 has routed 600000 rows
# (pid=23883) proces 41 has routed 300000 rows
# (pid=23882) proces 42 has routed 0 rows
# (pid=23884) proces 40 has routed 700000 rows
# (pid=23881) exit data routing process 38 .
# (pid=23882) proces 42 has routed 100000 rows
# (pid=23883) proces 41 has routed 400000 rows
# (pid=23881) enter data routing process 43 ..
# (pid=23884) proces 40 has routed 800000 rows
# (pid=23881) proces 43 has routed 0 rows
# (pid=23882) proces 42 has routed 200000 rows
# (pid=23883) proces 41 has routed 500000 rows
# (pid=23884) proces 40 has routed 900000 rows
# (pid=23881) proces 43 has routed 100000 rows
# (pid=23882) proces 42 has routed 300000 rows
# (pid=23881) proces 43 has routed 200000 rows
# (pid=23884) proces 40 has routed 1000000 rows
# (pid=23882) proces 42 has routed 400000 rows
# (pid=23883) proces 41 has routed 600000 rows
# (pid=23881) proces 43 has routed 300000 rows
# (pid=23884) proces 40 has routed 1100000 rows
# (pid=23882) proces 42 has routed 500000 rows
# (pid=23883) proces 41 has routed 700000 rows
# (pid=23881) proces 43 has routed 400000 rows
# (pid=23884) proces 40 has routed 1200000 rows
# (pid=23882) proces 42 has routed 600000 rows
# (pid=23881) proces 43 has routed 500000 rows
# (pid=23883) proces 41 has routed 800000 rows
# (pid=23884) proces 40 has routed 1300000 rows
# (pid=23882) proces 42 has routed 700000 rows
# (pid=23881) proces 43 has routed 600000 rows
# (pid=23884) proces 40 has routed 1400000 rows
# (pid=23882) proces 42 has routed 800000 rows
# (pid=23883) proces 41 has routed 900000 rows
# (pid=23881) proces 43 has routed 700000 rows
# (pid=23884) proces 40 has routed 1500000 rows
# (pid=23882) proces 42 has routed 900000 rows
# (pid=23883) proces 41 has routed 1000000 rows
# (pid=23881) proces 43 has routed 800000 rows
# (pid=23884) proces 40 has routed 1600000 rows
# (pid=23882) proces 42 has routed 1000000 rows
# (pid=23881) proces 43 has routed 900000 rows
# (pid=23883) proces 41 has routed 1100000 rows
# (pid=23884) proces 40 has routed 1700000 rows
# (pid=23882) proces 42 has routed 1100000 rows
# (pid=23881) proces 43 has routed 1000000 rows
# (pid=23884) proces 40 has routed 1800000 rows
# (pid=23882) proces 42 has routed 1200000 rows
# (pid=23883) proces 41 has routed 1200000 rows
# (pid=23881) proces 43 has routed 1100000 rows
# (pid=23884) proces 40 has routed 1900000 rows
# (pid=23882) proces 42 has routed 1300000 rows= = = Finish Dump For Chunk 36
# (pid=23883) proces 41 has routed 1300000 rows
# (pid=23881) proces 43 has routed 1200000 rows
# to 39 = = =
# = = = TOTAL PROCESSED SO FAR: 80000000 ROWS. TIME SPENT: 1078.2460064888 SECONDS = = =
# (pid=23882) proces 42 has routed 1400000 rows
# (pid=23881) proces 43 has routed 1300000 rowsreading chunk:  44
#
# (pid=23883) proces 41 has routed 1400000 rows
# (pid=23884) exit data routing process 40 .
# (pid=23882) proces 42 has routed 1500000 rows
# (pid=23884) enter data routing process 44 ..
# (pid=23881) proces 43 has routed 1400000 rows
# (pid=23884) proces 44 has routed 0 rows
# reading chunk:  45
# (pid=23882) proces 42 has routed 1600000 rows
# (pid=23883) proces 41 has routed 1500000 rows
# (pid=23881) proces 43 has routed 1500000 rows
# (pid=23884) proces 44 has routed 100000 rows
# (pid=23882) proces 42 has routed 1700000 rows
# reading chunk:  46
# (pid=23881) proces 43 has routed 1600000 rows
# (pid=23883) proces 41 has routed 1600000 rows
# (pid=23884) proces 44 has routed 200000 rows
# (pid=23882) proces 42 has routed 1800000 rows
# (pid=23881) proces 43 has routed 1700000 rows
# (pid=23884) proces 44 has routed 300000 rows
# reading chunk:  47
# (pid=23882) proces 42 has routed 1900000 rows
# (pid=23883) proces 41 has routed 1700000 rows
# = = = Process Dump For Chunk 40 to 43 = = =
# (pid=23881) proces 43 has routed 1800000 rows
# (pid=23884) proces 44 has routed 400000 rows
# (pid=23883) proces 41 has routed 1800000 rows
# (pid=23881) proces 43 has routed 1900000 rows
# (pid=23884) proces 44 has routed 500000 rows
# (pid=23882) exit data routing process 42 .
# (pid=23883) proces 41 has routed 1900000 rows
# (pid=23884) proces 44 has routed 600000 rows
# (pid=23882) enter data routing process 45 ..
# (pid=23882) proces 45 has routed 0 rows
# (pid=23881) exit data routing process 43 .
# (pid=23884) proces 44 has routed 700000 rows
# (pid=23882) proces 45 has routed 100000 rows
# (pid=23881) enter data routing process 46 ..
# (pid=23881) proces 46 has routed 0 rows
# (pid=23884) proces 44 has routed 800000 rows
# (pid=23882) proces 45 has routed 200000 rows
# (pid=23883) exit data routing process 41 .
# (pid=23881) proces 46 has routed 100000 rows
# (pid=23884) proces 44 has routed 900000 rows
# (pid=23883) enter data routing process 47 ..
# (pid=23882) proces 45 has routed 300000 rows
# (pid=23883) proces 47 has routed 0 rows
# (pid=23881) proces 46 has routed 200000 rows
# (pid=23884) proces 44 has routed 1000000 rows
# (pid=23883) proces 47 has routed 100000 rows
# (pid=23882) proces 45 has routed 400000 rows
# (pid=23884) proces 44 has routed 1100000 rows
# (pid=23881) proces 46 has routed 300000 rows
# (pid=23883) proces 47 has routed 200000 rows
# (pid=23882) proces 45 has routed 500000 rows
# (pid=23881) proces 46 has routed 400000 rows
# (pid=23884) proces 44 has routed 1200000 rows
# (pid=23883) proces 47 has routed 300000 rows
# (pid=23882) proces 45 has routed 600000 rows
# (pid=23881) proces 46 has routed 500000 rows
# (pid=23884) proces 44 has routed 1300000 rows
# (pid=23883) proces 47 has routed 400000 rows
# (pid=23882) proces 45 has routed 700000 rows
# (pid=23884) proces 44 has routed 1400000 rows
# ...
# (pid=23881) enter data routing process 294 ..
# reading chunk:  295
# (pid=23881) proces 294 has routed 0 rows
# (pid=23882) proces 291 has routed 1500000 rows
# = = = Process Dump For Chunk 288 to 291 = = =
# (pid=23883) proces 292 has routed 300000 rows
# (pid=23884) proces 293 has routed 200000 rows
# (pid=23881) proces 294 has routed 100000 rows
# (pid=23883) proces 292 has routed 400000 rows
# (pid=23884) proces 293 has routed 300000 rows
# (pid=23882) proces 291 has routed 1600000 rows
# (pid=23881) proces 294 has routed 200000 rows
# (pid=23883) proces 292 has routed 500000 rows
# (pid=23884) proces 293 has routed 400000 rows
# (pid=23882) proces 291 has routed 1700000 rows
# (pid=23881) proces 294 has routed 300000 rows
# (pid=23883) proces 292 has routed 600000 rows
# (pid=23884) proces 293 has routed 500000 rows
# (pid=23882) proces 291 has routed 1800000 rows
# (pid=23881) proces 294 has routed 400000 rows
# (pid=23883) proces 292 has routed 700000 rows
# (pid=23884) proces 293 has routed 600000 rows
# (pid=23881) proces 294 has routed 500000 rows
# (pid=23882) proces 291 has routed 1900000 rows
# (pid=23883) proces 292 has routed 800000 rows
# (pid=23884) proces 293 has routed 700000 rows
# (pid=23881) proces 294 has routed 600000 rows
# (pid=23883) proces 292 has routed 900000 rows
# (pid=23884) proces 293 has routed 800000 rows
# (pid=23881) proces 294 has routed 700000 rows
# (pid=23883) proces 292 has routed 1000000 rows
# (pid=23882) exit data routing process 291 .
# (pid=23884) proces 293 has routed 900000 rows
# (pid=23881) proces 294 has routed 800000 rows
# (pid=23882) enter data routing process 295 ..
# (pid=23883) proces 292 has routed 1100000 rows
# (pid=23882) proces 295 has routed 0 rows
# (pid=23884) proces 293 has routed 1000000 rows
# (pid=23881) proces 294 has routed 900000 rows
# (pid=23883) proces 292 has routed 1200000 rows
# (pid=23882) proces 295 has routed 100000 rows
# (pid=23884) proces 293 has routed 1100000 rows
# (pid=23881) proces 294 has routed 1000000 rows
# (pid=23883) proces 292 has routed 1300000 rows
# (pid=23882) proces 295 has routed 200000 rows
# (pid=23884) proces 293 has routed 1200000 rows
# (pid=23881) proces 294 has routed 1100000 rows
# (pid=23883) proces 292 has routed 1400000 rows
# (pid=23882) proces 295 has routed 300000 rows
# (pid=23884) proces 293 has routed 1300000 rows
# (pid=23881) proces 294 has routed 1200000 rows
# (pid=23883) proces 292 has routed 1500000 rows
# (pid=23882) proces 295 has routed 400000 rows
# (pid=23884) proces 293 has routed 1400000 rows
# (pid=23881) proces 294 has routed 1300000 rows
# (pid=23883) proces 292 has routed 1600000 rows
# (pid=23882) proces 295 has routed 500000 rows
# (pid=23884) proces 293 has routed 1500000 rows
# (pid=23881) proces 294 has routed 1400000 rows
# (pid=23883) proces 292 has routed 1700000 rows
# (pid=23882) proces 295 has routed 600000 rows
# (pid=23884) proces 293 has routed 1600000 rows
# (pid=23881) proces 294 has routed 1500000 rows
# (pid=23883) proces 292 has routed 1800000 rows
# (pid=23884) proces 293 has routed 1700000 rows
# (pid=23882) proces 295 has routed 700000 rows
# (pid=23881) proces 294 has routed 1600000 rows
# (pid=23883) proces 292 has routed 1900000 rows
# (pid=23884) proces 293 has routed 1800000 rows
# (pid=23882) proces 295 has routed 800000 rows
# (pid=23881) proces 294 has routed 1700000 rows
# (pid=23882) proces 295 has routed 900000 rows
# (pid=23884) proces 293 has routed 1900000 rows
# (pid=23881) proces 294 has routed 1800000 rows
# (pid=23882) proces 295 has routed 1000000 rows
# (pid=23883) exit data routing process 292 .
# = = = Finish Dump For Chunk(pid=23881) proces 294 has routed 1900000 rows
# (pid=23882) proces 295 has routed 1100000 rows
#  288 to 291 = = =
# = = = TOTAL PROCESSED SO FAR: 584000000 ROWS. TIME SPENT: 7442.08353972435 SECONDS = = =
# (pid=23884) exit data routing process 293 .
# reading chunk:  296
# (pid=23882) proces 295 has routed 1200000 rows
# (pid=23881) exit data routing process 294 .
# (pid=23884) enter data routing process 296 ..
# (pid=23882) proces 295 has routed 1300000 rows
# (pid=23884) proces 296 has routed 0 rows
# reading chunk:  297
# (pid=23882) proces 295 has routed 1400000 rows
# (pid=23884) proces 296 has routed 100000 rows
# (pid=23881) enter data routing process 297 ..
# (pid=23881) proces 297 has routed 0 rows
# (pid=23884) proces 296 has routed 200000 rows
# reading chunk:  298
# (pid=23882) proces 295 has routed 1500000 rows
# (pid=23881) proces 297 has routed 100000 rows
# (pid=23883) enter data routing process 298 ..
# (pid=23884) proces 296 has routed 300000 rows
# (pid=23883) proces 298 has routed 0 rows
# (pid=23882) proces 295 has routed 1600000 rows
# reading chunk:  299
# (pid=23881) proces 297 has routed 200000 rows
# = = = Process Dump For Chunk 292 to 295 = = =
# (pid=23884) proces 296 has routed 400000 rows
# (pid=23883) proces 298 has routed 100000 rows
# (pid=23882) proces 295 has routed 1700000 rows
# (pid=23881) proces 297 has routed 300000 rows
# (pid=23883) proces 298 has routed 200000 rows
# (pid=23884) proces 296 has routed 500000 rows
# (pid=23882) proces 295 has routed 1800000 rows
# (pid=23881) proces 297 has routed 400000 rows
# (pid=23883) proces 298 has routed 300000 rows
# (pid=23884) proces 296 has routed 600000 rows
# (pid=23882) proces 295 has routed 1900000 rows
# (pid=23881) proces 297 has routed 500000 rows
# (pid=23883) proces 298 has routed 400000 rows
# (pid=23884) proces 296 has routed 700000 rows
# (pid=23881) proces 297 has routed 600000 rows
# (pid=23883) proces 298 has routed 500000 rows
# (pid=23884) proces 296 has routed 800000 rows
# (pid=23882) exit data routing process 295 .
# (pid=23881) proces 297 has routed 700000 rows
# (pid=23883) proces 298 has routed 600000 rows
# (pid=23884) proces 296 has routed 900000 rows
# (pid=23882) enter data routing process 299 ..
# (pid=23882) proces 299 has routed 0 rows
# (pid=23881) proces 297 has routed 800000 rows
# (pid=23883) proces 298 has routed 700000 rows
# (pid=23884) proces 296 has routed 1000000 rows
# (pid=23882) proces 299 has routed 100000 rows
# (pid=23881) proces 297 has routed 900000 rows
# (pid=23883) proces 298 has routed 800000 rows
# (pid=23884) proces 296 has routed 1100000 rows
# (pid=23882) proces 299 has routed 200000 rows
# (pid=23881) proces 297 has routed 1000000 rows
# (pid=23883) proces 298 has routed 900000 rows
# (pid=23884) proces 296 has routed 1200000 rows
# (pid=23882) proces 299 has routed 300000 rows
# (pid=23881) proces 297 has routed 1100000 rows
# (pid=23883) proces 298 has routed 1000000 rows
# (pid=23884) proces 296 has routed 1300000 rows
# (pid=23882) proces 299 has routed 400000 rows
# (pid=23881) proces 297 has routed 1200000 rows
# (pid=23883) proces 298 has routed 1100000 rows
# (pid=23884) proces 296 has routed 1400000 rows
# (pid=23882) proces 299 has routed 500000 rows
# (pid=23881) proces 297 has routed 1300000 rows
# (pid=23883) proces 298 has routed 1200000 rows
# (pid=23884) proces 296 has routed 1500000 rows
# (pid=23882) proces 299 has routed 600000 rows
# (pid=23881) proces 297 has routed 1400000 rows
# (pid=23883) proces 298 has routed 1300000 rows
# (pid=23884) proces 296 has routed 1600000 rows
# (pid=23882) proces 299 has routed 700000 rows
# (pid=23881) proces 297 has routed 1500000 rows
# (pid=23883) proces 298 has routed 1400000 rows
# (pid=23884) proces 296 has routed 1700000 rows
# (pid=23882) proces 299 has routed 800000 rows
# (pid=23881) proces 297 has routed 1600000 rows
# (pid=23883) proces 298 has routed 1500000 rows
# (pid=23884) proces 296 has routed 1800000 rows
# (pid=23882) proces 299 has routed 900000 rows
# (pid=23881) proces 297 has routed 1700000 rows
# (pid=23883) proces 298 has routed 1600000 rows
# (pid=23884) proces 296 has routed 1900000 rows
# (pid=23882) proces 299 has routed 1000000 rows
# (pid=23881) proces 297 has routed 1800000 rows
# (pid=23883) proces 298 has routed 1700000 rows
# (pid=23882) proces 299 has routed 1100000 rows
# (pid=23881) proces 297 has routed 1900000 rows
# (pid=23883) proces 298 has routed 1800000 rows
# = = = Finish Dump For Chunk 292 to (pid=23884) exit data routing process 296 .
# (pid=23882) proces 299 has routed 1200000 rows
# (pid=23883) proces 298 has routed 1900000 rows
# 295 = = =
# = = = TOTAL PROCESSED SO FAR: 592000000 ROWS. TIME SPENT: 7545.4178721904755 SECONDS = = =
# reading chunk:  300
# = = = Process Dump For Last Few Chunks = = =
# (pid=23884) enter data routing process 300 ..
# (pid=23884) proces 300 has routed 0 rows
# (pid=23884) exit data routing process 300 .
# (pid=23882) proces 299 has routed 1300000 rows
# (pid=23881) exit data routing process 297 .
# (pid=23882) proces 299 has routed 1400000 rows
# (pid=23883) exit data routing process 298 .
# (pid=23882) proces 299 has routed 1500000 rows
# (pid=23882) proces 299 has routed 1600000 rows
# (pid=23882) proces 299 has routed 1700000 rows
# (pid=23882) proces 299 has routed 1800000 rows
# (pid=23882) proces 299 has routed 1900000 rows
# (pid=23882) exit data routing process 299 .
# = = = Start Merging the Epochs = = =
# (pid=23884) 2021-07-02 12:25:05,500 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# (pid=23883) 2021-07-02 12:25:05,505 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# (pid=23882) 2021-07-02 12:25:05,502 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# (pid=23881) 2021-07-02 12:25:05,496 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# (pid=23883) process 2 pid 194  len parquets (epochs): 76
# (pid=23884) process 3 pid 135  len parquets (epochs): 76
# (pid=23881) process 1 pid 77  len parquets (epochs): 76
# (pid=23883) process 2 pid 197  len parquets (epochs): 76
# (pid=23882) process 0 pid 165  len parquets (epochs): 76
# (pid=23884) process 3 pid 92  len parquets (epochs): 76
# (pid=23883) process 2 pid 198  len parquets (epochs): 76
# (pid=23881) process 1 pid 43  len parquets (epochs): 76
# (pid=23884) process 3 pid 93  len parquets (epochs): 76
# (pid=23883) process 2 pid 199  len parquets (epochs): 76
# (pid=23883) process 2 pid 200  len parquets (epochs): 76
# (pid=23882) process 0 pid 166  len parquets (epochs): 76
# (pid=23883) process 2 pid 207  len parquets (epochs): 76
# (pid=23884) process 3 pid 94  len parquets (epochs): 76
# (pid=23883) process 2 pid 208  len parquets (epochs): 76
# (pid=23884) process 3 pid 95  len parquets (epochs): 76
# (pid=23883) process 2 pid 209  len parquets (epochs): 76
# (pid=23882) process 0 pid 167  len parquets (epochs): 76
# (pid=23883) process 2 pid 210  len parquets (epochs): 76
# (pid=23881) process 1 pid 44  len parquets (epochs): 76
# (pid=23883) process 2 pid 213  len parquets (epochs): 76
# (pid=23884) process 3 pid 96  len parquets (epochs): 76
# (pid=23883) process 2 pid 214  len parquets (epochs): 76
# (pid=23883) process 2 pid 215  len parquets (epochs): 76
# (pid=23882) process 0 pid 168  len parquets (epochs): 76
# (pid=23884) process 3 pid 97  len parquets (epochs): 76
# (pid=23883) process 2 pid 216  len parquets (epochs): 76
# (pid=23881) process 1 pid 124  len parquets (epochs): 76
# (pid=23882) process 0 pid 63  len parquets (epochs): 76
# (pid=23883) process 2 pid 221  len parquets (epochs): 76
# (pid=23881) process 1 pid 157  len parquets (epochs): 76
# (pid=23883) process 2 pid 222  len parquets (epochs): 76
# (pid=23881) process 1 pid 126  len parquets (epochs): 76
# (pid=23884) process 3 pid 136  len parquets (epochs): 76
# (pid=23883) process 2 pid 223  len parquets (epochs): 76
# (pid=23882) process 0 pid 64  len parquets (epochs): 76
# (pid=23883) process 2 pid 224  len parquets (epochs): 76
# (pid=23881) process 1 pid 80  len parquets (epochs): 76
# (pid=23883) process 2 pid 227  len parquets (epochs): 76
# (pid=23884) process 3 pid 99  len parquets (epochs): 76
# (pid=23884) process 3 pid 100  len parquets (epochs): 76
# (pid=23883) process 2 pid 228  len parquets (epochs): 76
# (pid=23881) process 1 pid 127  len parquets (epochs): 76
# (pid=23883) process 2 pid 229  len parquets (epochs): 76
# (pid=23881) process 1 pid 128  len parquets (epochs): 76
# (pid=23884) process 3 pid 101  len parquets (epochs): 76
# (pid=23883) process 2 pid 230  len parquets (epochs): 76
# (pid=23882) process 0 pid 113  len parquets (epochs): 76
# (pid=23884) process 3 pid 137  len parquets (epochs): 76
# (pid=23883) process 2 pid 87  len parquets (epochs): 76
# (pid=23881) process 1 pid 158  len parquets (epochs): 76
# (pid=23882) process 0 pid 114  len parquets (epochs): 76
# (pid=23884) process 3 pid 138  len parquets (epochs): 76
# (pid=23883) process 2 pid 88  len parquets (epochs): 76
# (pid=23882) process 0 pid 115  len parquets (epochs): 76
# (pid=23881) process 1 pid 159  len parquets (epochs): 76
# (pid=23884) process 3 pid 139  len parquets (epochs): 76
# (pid=23882) process 0 pid 116  len parquets (epochs): 76
# (pid=23881) process 1 pid 160  len parquets (epochs): 76
# (pid=23883) process 2 pid 89  len parquets (epochs): 76
# (pid=23884) process 3 pid 140  len parquets (epochs): 76
# (pid=23882) process 0 pid 154  len parquets (epochs): 76
# (pid=23884) process 3 pid 104  len parquets (epochs): 76
# (pid=23883) process 2 pid 161  len parquets (epochs): 76
# (pid=23882) process 0 pid 155  len parquets (epochs): 76
# (pid=23881) process 1 pid 131  len parquets (epochs): 76
# (pid=23884) process 3 pid 141  len parquets (epochs): 76
# (pid=23883) process 2 pid 162  len parquets (epochs): 76
# (pid=23882) process 0 pid 156  len parquets (epochs): 76
# (pid=23883) process 2 pid 134  len parquets (epochs): 76
# (pid=23884) process 3 pid 142  len parquets (epochs): 76
# (pid=23883) exit merge process 2
# (pid=23881) process 1 pid 84  len parquets (epochs): 76
# (pid=23881) process 1 pid 85  len parquets (epochs): 76
# (pid=23882) process 0 pid 119  len parquets (epochs): 76
# (pid=23881) process 1 pid 132  len parquets (epochs): 76
# (pid=23884) process 3 pid 106  len parquets (epochs): 76
# (pid=23881) process 1 pid 177  len parquets (epochs): 76
# (pid=23881) process 1 pid 178  len parquets (epochs): 76
# (pid=23884) process 3 pid 143  len parquets (epochs): 76
# (pid=23881) process 1 pid 179  len parquets (epochs): 76
# (pid=23884) process 3 pid 144  len parquets (epochs): 76
# (pid=23881) process 1 pid 180  len parquets (epochs): 76
# (pid=23884) process 3 pid 145  len parquets (epochs): 76
# (pid=23881) process 1 pid 183  len parquets (epochs): 76
# (pid=23884) process 3 pid 146  len parquets (epochs): 76
# (pid=23881) process 1 pid 184  len parquets (epochs): 76
# (pid=23884) process 3 pid 147  len parquets (epochs): 76
# (pid=23881) process 1 pid 185  len parquets (epochs): 76
# (pid=23881) process 1 pid 186  len parquets (epochs): 76
# (pid=23884) process 3 pid 148  len parquets (epochs): 76
# (pid=23881) process 1 pid 191  len parquets (epochs): 76
# (pid=23884) process 3 pid 149  len parquets (epochs): 76
# (pid=23881) process 1 pid 192  len parquets (epochs): 76
# (pid=23884) process 3 pid 150  len parquets (epochs): 76
# (pid=23882) process 0 pid 35  len parquets (epochs): 76
# (pid=23881) process 1 pid 193  len parquets (epochs): 76
# (pid=23884) process 3 pid 151  len parquets (epochs): 76
# (pid=23881) exit merge process 1
# (pid=23884) process 3 pid 152  len parquets (epochs): 76
# (pid=23884) process 3 pid 153  len parquets (epochs): 76
# (pid=23884) exit merge process 3
# (pid=23882) process 0 pid 36  len parquets (epochs): 76
# (pid=23882) process 0 pid 37  len parquets (epochs): 76
# (pid=23882) process 0 pid 38  len parquets (epochs): 76
# (pid=23882) process 0 pid 120  len parquets (epochs): 76
# (pid=23882) process 0 pid 121  len parquets (epochs): 76
# (pid=23882) process 0 pid 122  len parquets (epochs): 76
# (pid=23882) process 0 pid 71  len parquets (epochs): 76
# (pid=23882) process 0 pid 72  len parquets (epochs): 76
# (pid=23882) process 0 pid 123  len parquets (epochs): 76
# (pid=23882) process 0 pid 74  len parquets (epochs): 76
# (pid=23882) process 0 pid 75  len parquets (epochs): 76
# (pid=23882) process 0 pid 76  len parquets (epochs): 76
# (pid=23882) exit merge process 0
# = = = = = TOTAL DATA ROUTING AND PERISITING TIME: 8458.043516635895 = = = = =
# finish kdtree data routing..

# %%
ray.shutdown()

# %%
# import pyarrow as pa
# import pyarrow.parquet as pq
# fs = pa.hdfs.connect()

# %%
# # read every parquet and dump it, see if it has a difference in query response time
# # use pyarrow !!!
# start_time = time.time()
# for i in range(421):
#     print("processing", i, "..")
#     pid = i
#     read_path = nora_hdfs + 'partition_' + str(pid)+'.parquet'
#     save_path = nora_hdfs + 'reorganized/partition_' + str(pid)+'.parquet'
#     adf = pq.read_table(read_path)
#     print('done read parquet from path')
#     fw = fs.open(save_path, 'wb')
#     print("start writing..")
#     pq.write_table(adf, fw)
#     fw.close()
# end_time = time.time()
# print('parquet merge time:',end_time-start_time)

# %%
# start_time = time.time()
# for i in range(68):
#     print("processing", i, "..")
#     pid = i
#     read_path = qdtree_hdfs + 'partition_' + str(pid)+'.parquet'
#     save_path = qdtree_hdfs + 'reorganized/partition_' + str(pid)+'.parquet'
#     adf = pq.read_table(read_path)
#     print('done read parquet from path')
#     fw = fs.open(save_path, 'wb')
#     print("start writing..")
#     pq.write_table(adf, fw)
#     fw.close()
# end_time = time.time()
# print('parquet merge time:',end_time-start_time)

# %%
# start_time = time.time()
# for i in range(512):
#     print("processing", i, "..")
#     pid = i
#     read_path = kdtree_hdfs + 'partition_' + str(pid)+'.parquet'
#     save_path = kdtree_hdfs + 'reorganized/partition_' + str(pid)+'.parquet'
#     adf = pq.read_table(read_path)
#     print('done read parquet from path')
#     fw = fs.open(save_path, 'wb')
#     print("start writing..")
#     pq.write_table(adf, fw)
#     fw.close()
# end_time = time.time()
# print('parquet merge time:',end_time-start_time)
